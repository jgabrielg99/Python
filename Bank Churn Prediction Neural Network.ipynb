# %% [markdown]
# <a href="https://colab.research.google.com/github/jgabrielg99/Python/blob/main/Bank%20Churn%20Prediction%20Neural%20Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><font size=6> Bank Churn Prediction </font></center>

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Context

# %% [markdown]
# Businesses like banks which provide service have to worry about problem of 'Customer Churn' i.e. customers leaving and joining another service provider. It is important to understand which aspects of the service influence a customer's decision in this regard. Management can concentrate efforts on improvement of service, keeping in mind these priorities.

# %% [markdown]
# ### Objective

# %% [markdown]
# You as a Data scientist with the  bank need to  build a neural network based classifier that can determine whether a customer will leave the bank  or not in the next 6 months.

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# * CustomerId: Unique ID which is assigned to each customer
#
# * Surname: Last name of the customer
#
# * CreditScore: It defines the credit history of the customer.
#
# * Geography: A customer’s location
#
# * Gender: It defines the Gender of the customer
#
# * Age: Age of the customer
#
# * Tenure: Number of years for which the customer has been with the bank
#
# * NumOfProducts: refers to the number of products that a customer has purchased through the bank.
#
# * Balance: Account balance
#
# * HasCrCard: It is a categorical variable which decides whether the customer has credit card or not.
#
# * EstimatedSalary: Estimated salary
#
# * isActiveMember: Is is a categorical variable which decides whether the customer is active member of the bank or not ( Active member in the sense, using bank products regularly, making transactions etc )
#
# * Exited : whether or not the customer left the bank within six month. It can take two values
# ** 0=No ( Customer did not leave the bank )
# ** 1=Yes ( Customer left the bank )

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, recall_score, accuracy_score, precision_score, f1_score
from sklearn.utils import class_weight

from imblearn.over_sampling import SMOTE

import tensorflow as tf
from tensorflow import keras
from keras import backend
from keras.models import Sequential
from keras.layers import Dense, Dropout, InputLayer, BatchNormalization
from keras.optimizers import SGD, Adam

import random

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/AIML Course/Files/Churn.csv')
df = data.copy()

# %% [markdown]
# ## Data Overview

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# * There are 10,000 rows and 14 columns in this dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# * There don't appear to be any missing values in any of the columns
# * RowNumber, CustomerID, and Surname are all identifiers and will be dropped
# * Geography and Gender should be categorically encoded

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['CustomerId'].nunique()
# Out:
# 10000

# %%
df.drop(['RowNumber','CustomerId','Surname'], inplace=True, axis=1)

# %%
df.nunique()
# Out:
# CreditScore         460
# Geography             3
# Gender                2
# Age                  70
# Tenure               11
# Balance            6382
# NumOfProducts         4
# HasCrCard             2
# IsActiveMember        2
# EstimatedSalary    9999
# Exited                2
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %%
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a triangle will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
# function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %%
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
histogram_boxplot(df, 'CreditScore')

# %% [markdown]
# * Credit Score mainly has a normal distribution, maybe very slightly left skewed
#   * There a few outliers at the lower end of the data
#   * There are a large number of customers (~300) that have the maximum credit score (850)
#   * The average credit score is around 650

# %%
labeled_barplot(df, 'Geography')

# %% [markdown]
# * There are only 3 geographical locations in this dataset
#   * Approximately half of the customers are located in France
#   * A quarter of the customers are located in Germany and Spain

# %%
labeled_barplot(df, 'Gender')

# %%
df['Gender'].value_counts(normalize=True)
# Out:
# Gender
# Male      0.5457
# Female    0.4543
# Name: proportion, dtype: float64

# %% [markdown]
# * 55% of the data is male; 45% is female

# %%
histogram_boxplot(df, 'Age')

# %% [markdown]
# * The data is right skewed with a few values that have a significantly higher count
#   * There are several outliers in at the higher end of the data
#   * The average age is around 38-39

# %%
histogram_boxplot(df, 'Tenure')

# %% [markdown]
# * Tenure is very evenly distributed
#   * 0 and 10 years are the least common values; all other values have around 1000 customers
#   * The average tenure is 5 years

# %%
histogram_boxplot(df, 'Balance')

# %% [markdown]
# * Over a third of the data set has no revolving account balance
# * Otherwise, the data has normal distribution
#   * Because of the large number of 0 balance accounts, the average of the dataset is approximately 75,000

# %%
labeled_barplot(df, 'NumOfProducts')

# %% [markdown]
# * The vast majority of customers have purchased 1 or 2 products from the bank

# %%
labeled_barplot(df, 'HasCrCard')

# %%
df['HasCrCard'].value_counts(normalize=True)
# Out:
# HasCrCard
# 1    0.7055
# 0    0.2945
# Name: proportion, dtype: float64

# %% [markdown]
# * 70% of customers have a credit card

# %%
labeled_barplot(df, 'IsActiveMember')

# %% [markdown]
# * This data is split fairly evenly with slightly more customers being a member

# %%
histogram_boxplot(df, 'EstimatedSalary')

# %% [markdown]
# * Estimated Salary is very evenly split
#   * No outliers
#   * Average salary is 100,000

# %%
labeled_barplot(df, 'Exited')

# %%
df['Exited'].value_counts(normalize=True)
# Out:
# Exited
# 0    0.7963
# 1    0.2037
# Name: proportion, dtype: float64

# %% [markdown]
# * This data is quite imbalanced
# * Our target variable seems rather similar to the values of HasCrCard

# %% [markdown]
# ### Bivariate Analysis

# %%
# function to plot stacked bar chart

def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 1, 5))
    plt.legend(
        loc="lower left", frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %%
### Function to plot distributions

def distribution_plot_wrt_target(data, predictor, target):

    fig, axs = plt.subplots(2, 2, figsize=(12, 10))

    target_uniq = data[target].unique()

    axs[0, 0].set_title("Distribution of target for target=" + str(target_uniq[0]))
    sns.histplot(
        data=data[data[target] == target_uniq[0]],
        x=predictor,
        kde=True,
        ax=axs[0, 0],
        color="teal",
    )

    axs[0, 1].set_title("Distribution of target for target=" + str(target_uniq[1]))
    sns.histplot(
        data=data[data[target] == target_uniq[1]],
        x=predictor,
        kde=True,
        ax=axs[0, 1],
        color="orange",
    )

    axs[1, 0].set_title("Boxplot w.r.t target")
    sns.boxplot(data=data, x=target, y=predictor, ax=axs[1, 0], palette="gist_rainbow")

    axs[1, 1].set_title("Boxplot (without outliers) w.r.t target")
    sns.boxplot(
        data=data,
        x=target,
        y=predictor,
        ax=axs[1, 1],
        showfliers=False,
        palette="gist_rainbow",
    )

    plt.tight_layout()
    plt.show()

# %%
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
distribution_plot_wrt_target(df, 'CreditScore', 'Exited')

# %% [markdown]
# * The distribution of customers in both classes is very similar

# %%
stacked_barplot(df, 'Geography', 'Exited')
# Out:
# Exited        0     1    All
# Geography
# All        7963  2037  10000
# Germany    1695   814   2509
# France     4204   810   5014
# Spain      2064   413   2477
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# * More customers located in Germany churned than any other location (appox. 33%)

# %%
stacked_barplot(df, 'Gender', 'Exited')
# Out:
# Exited     0     1    All
# Gender
# All     7963  2037  10000
# Female  3404  1139   4543
# Male    4559   898   5457
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# * More females churned than males

# %%
distribution_plot_wrt_target(df, 'Age', 'Exited')

# %% [markdown]
# * Customers that churned on average tended to be older
#   * The average age of customer that stayed is around 36, while the average age of customers that exited is around 45

# %%
distribution_plot_wrt_target(df, 'Tenure', 'Exited')

# %% [markdown]
# * Surprisingly, the length of tenure does not appear to play a significant role in churn rate
#   * Brand loyalty may not be as important of a factor here

# %%
distribution_plot_wrt_target(df, 'Balance', 'Exited')

# %% [markdown]
# * Customers that churned tended to have a slightly higher balance

# %%
stacked_barplot(df, 'NumOfProducts', 'Exited')
# Out:
# Exited            0     1    All
# NumOfProducts
# All            7963  2037  10000
# 1              3675  1409   5084
# 2              4242   348   4590
# 3                46   220    266
# 4                 0    60     60
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# * All customers with 4 products purchased exited; the vast majority of customers with 3 also exited
# * Customers with 2 products were the most likely to remain with the bank

# %%
stacked_barplot(df, 'HasCrCard', 'Exited')
# Out:
# Exited        0     1    All
# HasCrCard
# All        7963  2037  10000
# 1          5631  1424   7055
# 0          2332   613   2945
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# * No correlation between owning a credit card and churning

# %%
stacked_barplot(df, 'IsActiveMember', 'Exited')
# Out:
# Exited             0     1    All
# IsActiveMember
# All             7963  2037  10000
# 0               3547  1302   4849
# 1               4416   735   5151
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# * Members are less likely to exit

# %%
distribution_plot_wrt_target(df, 'EstimatedSalary', 'Exited')

# %% [markdown]
# * No correlation between Estimated Salary and Exiting

# %%
cols_list = ["CreditScore","Age","Tenure","Balance","EstimatedSalary"]

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(df[cols_list].corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Dummy Variable Creation

# %%
cat_cols = [df.columns[i] for i in range(df.shape[1]) if df.dtypes[i]=='object']

# %%
df = pd.get_dummies(df, cat_cols, drop_first=True)

# %% [markdown]
# * Geography and Gender are now encoded as categorical features

# %% [markdown]
# ### Train-validation-test Split

# %%
X = df.drop('Exited', axis=1)
y = df['Exited']

# %%
X_big, X_test, y_big, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y, shuffle=True)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_big, y_big, test_size=0.2, random_state=1, stratify=y_big, shuffle=True)

# %%
X_train = X_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
X_val = X_val.reset_index(drop=True)
y_val = y_val.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
print(f' X_train: {X_train.shape} X_val: {X_val.shape} X_test: {X_test.shape}')
print(f' y_train: {y_train.shape[0]} y_val: {y_val.shape[0]} y_test: {y_test.shape[0]}')
# Out:
#  X_train: (6400, 11) X_val: (1600, 11) X_test: (2000, 11)
#  y_train: 6400 y_val: 1600 y_test: 2000

# %% [markdown]
# * The dataset has been split into training and test sets to be use when building our models
#   * The training set is further split into training and validation set to avoid data leakage

# %% [markdown]
# ### Data Normalization

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# * Scaling the data ensures that the ranges of each variable are equal so one variable isn't measured as more important than another

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Model Evaluation Criterion

# %% [markdown]
# Write down the logic for choosing the metric that would be the best metric for this business scenario.

# %% [markdown]
# ### **A Model can make wrong predictions in the following ways:**
# 1. Predicts a customers will churn, but they don't
# 2. Predicts a customer won't churn, but they do
#
# ### **Which case is more important?**
# In this case, we will want to minimize the number model predictions that a customer won't churn, but they do end up leaving the bank. This scenario is simply lost revenue. If the bank expends some resources to keep a customer that isn't planning on leaving, there is not a huge loss.
#
# ### **How to reduce this loss?**
# In order to reduce the number of false negative predictions, we will need to minimize the recall score of the model.
#
# There is a class imbalance in the dataset, so we will be utilizing class weights to allow the model to give proportionally more weight to the minority class.

# %%
def plot_loss(history, name):
    """
    Function to plot loss/accuracy

    history: an object which stores the metrics and losses.
    name: can be one of Loss or Accuracy
    """
    fig, ax = plt.subplots() #Creating a subplot with figure and axes.
    plt.plot(history.history[name]) #Plotting the train accuracy or train loss
    plt.plot(history.history['val_'+name]) #Plotting the validation accuracy or validation loss

    plt.title('Model ' + name.capitalize()) #Defining the title of the plot.
    plt.ylabel(name.capitalize()) #Capitalizing the first letter.
    plt.xlabel('Epoch') #Defining the label for the x-axis.
    fig.legend(['Train', 'Validation'], loc="outside right upper") #Defining the legend, loc controls the position of the legend.

# %%
def plot_recall(history, name):
    """
    Function to plot recall

    history: an object which stores the metrics and losses.
    name: can be one of Loss or Accuracy
    """
    fig, ax = plt.subplots()
    plt.plot(history.history['recall'])
    plt.plot(history.history['val_recall'])

    plt.title('Model Recall')
    plt.ylabel('Recall')
    plt.xlabel('Epoch')
    fig.legend(['Train', 'Validation'], loc="outside right upper")
    plt.show()

# %%
# defining a function to compute different metrics to check performance of a classification model built using statsmodels
def model_performance_classification(
    model, predictors, target, threshold=0.5
):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    threshold: threshold for classifying the observation as class 1
    """

    # checking which probabilities are greater than threshold
    pred = model.predict(predictors) > threshold
    # pred_temp = model.predict(predictors) > threshold
    # # rounding off the above values to get classes
    # pred = np.round(pred_temp)

    acc = accuracy_score(target, pred)  # to compute Accuracy
    recall = recall_score(target, pred)  # to compute Recall
    precision = precision_score(target, pred)  # to compute Precision
    f1 = f1_score(target, pred)  # to compute F1-score

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {"Accuracy": acc, "Recall": recall, "Precision": precision, "F1 Score": f1,},
        index=[0],
    )

    return df_perf

# %%
# Calculate class weights for imbalanced dataset
cw = (y_train.shape[0]) / np.bincount(y_train)

# Create a dictionary mapping class indices to their respective class weights
cw_dict = {}
for i in range(cw.shape[0]):
    cw_dict[i] = cw[i]

cw_dict
# Out:
# {0: np.float64(1.2558869701726845), 1: np.float64(4.9079754601226995)}

# %% [markdown]
# ### Neural Network with SGD Optimizer

# %% [markdown]
# * The first models will be a neural network consisting of
#   * Two hidden layers with 64 and 32 neurons
#   * Activation function of ReLU
#   * Optimizer is SGD

# %%
# clears the current Keras session
tf.keras.backend.clear_session()
# setting the seed for random number generators for consistency
np.random.seed(1)
random.seed(1)
tf.random.set_seed(1)

# %%
batch_size = 64
epochs = 50

# %%
# creating the neural network
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,881 (11.25 KB)
#  Trainable params: 2,881 (11.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# defining model optimizer as SGD
optimizer = keras.optimizers.SGD()
model.compile(
              loss='binary_crossentropy',
              optimizer=optimizer,
              metrics=['recall'],
              )

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size = batch_size,
    epochs = epochs,
    class_weight = cw_dict,
    verbose=2
)
# Out:
# Epoch 1/50
# 100/100 - 1s - 13ms/step - loss: 1.3548 - recall: 0.7025 - val_loss: 0.6557 - val_recall: 0.6994
# Epoch 2/50
# 100/100 - 1s - 9ms/step - loss: 1.2528 - recall: 0.7163 - val_loss: 0.6080 - val_recall: 0.7117
# Epoch 3/50
# 100/100 - 0s - 3ms/step - loss: 1.1845 - recall: 0.7163 - val_loss: 0.5762 - val_recall: 0.7209
# Epoch 4/50
# 100/100 - 0s - 3ms/step - loss: 1.1375 - recall: 0.7193 - val_loss: 0.5549 - val_recall: 0.7209
# Epoch 5/50
# 100/100 - 0s - 3ms/step - loss: 1.1035 - recall: 0.7262 - val_loss: 0.5388 - val_recall: 0.7147
# Epoch 6/50
# 100/100 - 0s - 3ms/step - loss: 1.0760 - recall: 0.7331 - val_loss: 0.5250 - val_recall: 0.7178
# Epoch 7/50
# 100/100 - 0s - 3ms/step - loss: 1.0519 - recall: 0.7439 - val_loss: 0.5137 - val_recall: 0.7147
# Epoch 8/50
# 100/100 - 0s - 4ms/step - loss: 1.0302 - recall: 0.7469 - val_loss: 0.5026 - val_recall: 0.7270
# Epoch 9/50
# 100/100 - 0s - 3ms/step - loss: 1.0105 - recall: 0.7531 - val_loss: 0.4932 - val_recall: 0.7239
# Epoch 10/50
# 100/100 - 0s - 3ms/step - loss: 0.9925 - recall: 0.7607 - val_loss: 0.4849 - val_recall: 0.7423
# Epoch 11/50
# 100/100 - 0s - 3ms/step - loss: 0.9766 - recall: 0.7592 - val_loss: 0.4782 - val_recall: 0.7393
# Epoch 12/50
# 100/100 - 0s - 4ms/step - loss: 0.9634 - recall: 0.7600 - val_loss: 0.4725 - val_recall: 0.7362
# Epoch 13/50
# 100/100 - 1s - 7ms/step - loss: 0.9526 - recall: 0.7661 - val_loss: 0.4685 - val_recall: 0.7362
# Epoch 14/50
# 100/100 - 1s - 7ms/step - loss: 0.9437 - recall: 0.7653 - val_loss: 0.4648 - val_recall: 0.7423
# Epoch 15/50
# 100/100 - 1s - 7ms/step - loss: 0.9365 - recall: 0.7646 - val_loss: 0.4620 - val_recall: 0.7362
# Epoch 16/50
# 100/100 - 0s - 4ms/step - loss: 0.9305 - recall: 0.7676 - val_loss: 0.4595 - val_recall: 0.7362
# Epoch 17/50
# 100/100 - 1s - 7ms/step - loss: 0.9254 - recall: 0.7707 - val_loss: 0.4572 - val_recall: 0.7331
# Epoch 18/50
# 100/100 - 0s - 3ms/step - loss: 0.9211 - recall: 0.7699 - val_loss: 0.4557 - val_recall: 0.7301
# Epoch 19/50
# 100/100 - 0s - 3ms/step - loss: 0.9173 - recall: 0.7699 - val_loss: 0.4542 - val_recall: 0.7301
# Epoch 20/50
# 100/100 - 0s - 3ms/step - loss: 0.9138 - recall: 0.7707 - val_loss: 0.4527 - val_recall: 0.7270
# Epoch 21/50
# 100/100 - 0s - 3ms/step - loss: 0.9107 - recall: 0.7730 - val_loss: 0.4512 - val_recall: 0.7270
# Epoch 22/50
# 100/100 - 0s - 3ms/step - loss: 0.9078 - recall: 0.7738 - val_loss: 0.4500 - val_recall: 0.7239
# Epoch 23/50
# 100/100 - 0s - 3ms/step - loss: 0.9050 - recall: 0.7738 - val_loss: 0.4489 - val_recall: 0.7270
# Epoch 24/50
# 100/100 - 0s - 3ms/step - loss: 0.9024 - recall: 0.7722 - val_loss: 0.4478 - val_recall: 0.7270
# Epoch 25/50
# 100/100 - 0s - 3ms/step - loss: 0.9000 - recall: 0.7738 - val_loss: 0.4471 - val_recall: 0.7270
# Epoch 26/50
# 100/100 - 0s - 3ms/step - loss: 0.8977 - recall: 0.7753 - val_loss: 0.4462 - val_recall: 0.7270
# Epoch 27/50
# 100/100 - 0s - 3ms/step - loss: 0.8956 - recall: 0.7768 - val_loss: 0.4455 - val_recall: 0.7270
# Epoch 28/50
# 100/100 - 1s - 6ms/step - loss: 0.8936 - recall: 0.7745 - val_loss: 0.4449 - val_recall: 0.7239
# Epoch 29/50
# 100/100 - 0s - 4ms/step - loss: 0.8917 - recall: 0.7745 - val_loss: 0.4444 - val_recall: 0.7239
# Epoch 30/50
# 100/100 - 0s - 3ms/step - loss: 0.8899 - recall: 0.7745 - val_loss: 0.4438 - val_recall: 0.7239
# Epoch 31/50
# 100/100 - 0s - 3ms/step - loss: 0.8881 - recall: 0.7738 - val_loss: 0.4432 - val_recall: 0.7239
# Epoch 32/50
# 100/100 - 1s - 6ms/step - loss: 0.8864 - recall: 0.7730 - val_loss: 0.4424 - val_recall: 0.7239
# Epoch 33/50
# 100/100 - 0s - 3ms/step - loss: 0.8846 - recall: 0.7730 - val_loss: 0.4420 - val_recall: 0.7239
# Epoch 34/50
# 100/100 - 0s - 3ms/step - loss: 0.8830 - recall: 0.7722 - val_loss: 0.4414 - val_recall: 0.7239
# Epoch 35/50
# 100/100 - 0s - 3ms/step - loss: 0.8813 - recall: 0.7745 - val_loss: 0.4411 - val_recall: 0.7239
# Epoch 36/50
# 100/100 - 1s - 6ms/step - loss: 0.8798 - recall: 0.7761 - val_loss: 0.4404 - val_recall: 0.7239
# Epoch 37/50
# 100/100 - 0s - 4ms/step - loss: 0.8782 - recall: 0.7761 - val_loss: 0.4400 - val_recall: 0.7239
# Epoch 38/50
# 100/100 - 0s - 3ms/step - loss: 0.8767 - recall: 0.7776 - val_loss: 0.4396 - val_recall: 0.7239
# Epoch 39/50
# 100/100 - 0s - 3ms/step - loss: 0.8753 - recall: 0.7791 - val_loss: 0.4393 - val_recall: 0.7209
# Epoch 40/50
# 100/100 - 0s - 3ms/step - loss: 0.8739 - recall: 0.7814 - val_loss: 0.4387 - val_recall: 0.7209
# Epoch 41/50
# 100/100 - 1s - 6ms/step - loss: 0.8725 - recall: 0.7814 - val_loss: 0.4382 - val_recall: 0.7178
# Epoch 42/50
# 100/100 - 0s - 3ms/step - loss: 0.8712 - recall: 0.7822 - val_loss: 0.4376 - val_recall: 0.7178
# Epoch 43/50
# 100/100 - 0s - 3ms/step - loss: 0.8699 - recall: 0.7845 - val_loss: 0.4372 - val_recall: 0.7178
# Epoch 44/50
# 100/100 - 0s - 3ms/step - loss: 0.8686 - recall: 0.7845 - val_loss: 0.4369 - val_recall: 0.7178
# Epoch 45/50
# 100/100 - 0s - 3ms/step - loss: 0.8674 - recall: 0.7868 - val_loss: 0.4367 - val_recall: 0.7178
# Epoch 46/50
# 100/100 - 0s - 4ms/step - loss: 0.8662 - recall: 0.7891 - val_loss: 0.4365 - val_recall: 0.7178
# Epoch 47/50
# 100/100 - 1s - 7ms/step - loss: 0.8649 - recall: 0.7876 - val_loss: 0.4359 - val_recall: 0.7117
# Epoch 48/50
# 100/100 - 1s - 7ms/step - loss: 0.8638 - recall: 0.7891 - val_loss: 0.4358 - val_recall: 0.7117
# Epoch 49/50
# 100/100 - 0s - 4ms/step - loss: 0.8626 - recall: 0.7883 - val_loss: 0.4354 - val_recall: 0.7055
# Epoch 50/50
# 100/100 - 1s - 7ms/step - loss: 0.8614 - recall: 0.7891 - val_loss: 0.4354 - val_recall: 0.7055

# %%
plot_loss(history, 'loss')

# %%
plot_recall(history, 'recall')

# %%
model_train_perf = model_performance_classification(model, X_train, y_train)
model_train_perf
# Out:
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.820156  0.773006   0.541063  0.636565

# %%
model_val_perf = model_performance_classification(model, X_val, y_val)
model_val_perf
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.80125  0.705521    0.50885   0.59126

# %%
confusion_matrix(y_val, model.predict(X_val) > 0.05)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[ 183, 1091],
#        [   3,  323]])

# %% [markdown]
# * The recall score on the training data is aroudn 0.47 and is 0.43 on the validation set.
#   * While the score is fairly low, the model appears to do a good job of generalizing the data and is not overfit
#   * The rate of improvement over epochs is good

# %% [markdown]
# ## Model Performance Improvement

# %% [markdown]
# ### Neural Network with Adam Optimizer

# %% [markdown]
# * Now we'll try the same model, but use the Adam optimizer rather than SGD

# %%
# clears the current Keras session
tf.keras.backend.clear_session()

# %%
# creating the neural network
model_1 = Sequential()
model_1.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
model_1.add(Dense(32, activation='relu'))
model_1.add(Dense(1, activation='sigmoid'))

# %%
model_1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,881 (11.25 KB)
#  Trainable params: 2,881 (11.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = keras.optimizers.Adam()
model_1.compile(
    loss='binary_crossentropy',
    optimizer=optimizer,
    metrics=['recall']
)

# %%
history_1 = model_1.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size = batch_size,
    epochs = epochs,
    class_weight = cw_dict,
    verbose=2
)
# Out:
# Epoch 1/50
# 100/100 - 2s - 19ms/step - loss: 1.2529 - recall: 0.6979 - val_loss: 0.5767 - val_recall: 0.7086
# Epoch 2/50
# 100/100 - 0s - 3ms/step - loss: 1.1215 - recall: 0.7094 - val_loss: 0.5415 - val_recall: 0.7209
# Epoch 3/50
# 100/100 - 0s - 3ms/step - loss: 1.0537 - recall: 0.7370 - val_loss: 0.5108 - val_recall: 0.7393
# Epoch 4/50
# 100/100 - 1s - 6ms/step - loss: 0.9920 - recall: 0.7400 - val_loss: 0.4890 - val_recall: 0.7546
# Epoch 5/50
# 100/100 - 1s - 6ms/step - loss: 0.9513 - recall: 0.7561 - val_loss: 0.4787 - val_recall: 0.7607
# Epoch 6/50
# 100/100 - 0s - 3ms/step - loss: 0.9295 - recall: 0.7692 - val_loss: 0.4739 - val_recall: 0.7485
# Epoch 7/50
# 100/100 - 0s - 3ms/step - loss: 0.9160 - recall: 0.7738 - val_loss: 0.4711 - val_recall: 0.7577
# Epoch 8/50
# 100/100 - 1s - 6ms/step - loss: 0.9058 - recall: 0.7730 - val_loss: 0.4681 - val_recall: 0.7577
# Epoch 9/50
# 100/100 - 1s - 6ms/step - loss: 0.8977 - recall: 0.7776 - val_loss: 0.4663 - val_recall: 0.7546
# Epoch 10/50
# 100/100 - 0s - 3ms/step - loss: 0.8909 - recall: 0.7776 - val_loss: 0.4643 - val_recall: 0.7515
# Epoch 11/50
# 100/100 - 0s - 3ms/step - loss: 0.8848 - recall: 0.7799 - val_loss: 0.4633 - val_recall: 0.7485
# Epoch 12/50
# 100/100 - 0s - 4ms/step - loss: 0.8794 - recall: 0.7791 - val_loss: 0.4624 - val_recall: 0.7454
# Epoch 13/50
# 100/100 - 1s - 6ms/step - loss: 0.8742 - recall: 0.7807 - val_loss: 0.4616 - val_recall: 0.7454
# Epoch 14/50
# 100/100 - 0s - 3ms/step - loss: 0.8692 - recall: 0.7799 - val_loss: 0.4611 - val_recall: 0.7454
# Epoch 15/50
# 100/100 - 0s - 3ms/step - loss: 0.8645 - recall: 0.7830 - val_loss: 0.4599 - val_recall: 0.7485
# Epoch 16/50
# 100/100 - 0s - 4ms/step - loss: 0.8600 - recall: 0.7837 - val_loss: 0.4601 - val_recall: 0.7485
# Epoch 17/50
# 100/100 - 1s - 5ms/step - loss: 0.8555 - recall: 0.7860 - val_loss: 0.4589 - val_recall: 0.7454
# Epoch 18/50
# 100/100 - 1s - 6ms/step - loss: 0.8511 - recall: 0.7876 - val_loss: 0.4586 - val_recall: 0.7485
# Epoch 19/50
# 100/100 - 1s - 6ms/step - loss: 0.8470 - recall: 0.7899 - val_loss: 0.4575 - val_recall: 0.7485
# Epoch 20/50
# 100/100 - 1s - 5ms/step - loss: 0.8433 - recall: 0.7914 - val_loss: 0.4570 - val_recall: 0.7454
# Epoch 21/50
# 100/100 - 1s - 7ms/step - loss: 0.8396 - recall: 0.7929 - val_loss: 0.4565 - val_recall: 0.7423
# Epoch 22/50
# 100/100 - 1s - 6ms/step - loss: 0.8361 - recall: 0.7945 - val_loss: 0.4556 - val_recall: 0.7423
# Epoch 23/50
# 100/100 - 0s - 4ms/step - loss: 0.8326 - recall: 0.7945 - val_loss: 0.4556 - val_recall: 0.7423
# Epoch 24/50
# 100/100 - 0s - 3ms/step - loss: 0.8293 - recall: 0.7960 - val_loss: 0.4560 - val_recall: 0.7423
# Epoch 25/50
# 100/100 - 1s - 6ms/step - loss: 0.8259 - recall: 0.7968 - val_loss: 0.4555 - val_recall: 0.7423
# Epoch 26/50
# 100/100 - 0s - 3ms/step - loss: 0.8228 - recall: 0.7998 - val_loss: 0.4557 - val_recall: 0.7454
# Epoch 27/50
# 100/100 - 1s - 6ms/step - loss: 0.8194 - recall: 0.8006 - val_loss: 0.4549 - val_recall: 0.7485
# Epoch 28/50
# 100/100 - 0s - 3ms/step - loss: 0.8161 - recall: 0.8044 - val_loss: 0.4554 - val_recall: 0.7454
# Epoch 29/50
# 100/100 - 1s - 6ms/step - loss: 0.8131 - recall: 0.8083 - val_loss: 0.4554 - val_recall: 0.7423
# Epoch 30/50
# 100/100 - 0s - 3ms/step - loss: 0.8098 - recall: 0.8090 - val_loss: 0.4552 - val_recall: 0.7393
# Epoch 31/50
# 100/100 - 1s - 6ms/step - loss: 0.8068 - recall: 0.8083 - val_loss: 0.4557 - val_recall: 0.7362
# Epoch 32/50
# 100/100 - 1s - 6ms/step - loss: 0.8033 - recall: 0.8083 - val_loss: 0.4551 - val_recall: 0.7362
# Epoch 33/50
# 100/100 - 1s - 6ms/step - loss: 0.8003 - recall: 0.8083 - val_loss: 0.4545 - val_recall: 0.7362
# Epoch 34/50
# 100/100 - 0s - 5ms/step - loss: 0.7973 - recall: 0.8083 - val_loss: 0.4554 - val_recall: 0.7331
# Epoch 35/50
# 100/100 - 1s - 10ms/step - loss: 0.7945 - recall: 0.8113 - val_loss: 0.4549 - val_recall: 0.7301
# Epoch 36/50
# 100/100 - 1s - 11ms/step - loss: 0.7916 - recall: 0.8106 - val_loss: 0.4553 - val_recall: 0.7301
# Epoch 37/50
# 100/100 - 0s - 3ms/step - loss: 0.7887 - recall: 0.8121 - val_loss: 0.4547 - val_recall: 0.7331
# Epoch 38/50
# 100/100 - 1s - 6ms/step - loss: 0.7859 - recall: 0.8137 - val_loss: 0.4547 - val_recall: 0.7270
# Epoch 39/50
# 100/100 - 1s - 6ms/step - loss: 0.7835 - recall: 0.8137 - val_loss: 0.4561 - val_recall: 0.7301
# Epoch 40/50
# 100/100 - 0s - 3ms/step - loss: 0.7806 - recall: 0.8144 - val_loss: 0.4557 - val_recall: 0.7239
# Epoch 41/50
# 100/100 - 1s - 5ms/step - loss: 0.7781 - recall: 0.8144 - val_loss: 0.4556 - val_recall: 0.7209
# Epoch 42/50
# 100/100 - 1s - 6ms/step - loss: 0.7756 - recall: 0.8167 - val_loss: 0.4568 - val_recall: 0.7209
# Epoch 43/50
# 100/100 - 1s - 6ms/step - loss: 0.7729 - recall: 0.8175 - val_loss: 0.4562 - val_recall: 0.7301
# Epoch 44/50
# 100/100 - 0s - 5ms/step - loss: 0.7706 - recall: 0.8152 - val_loss: 0.4574 - val_recall: 0.7270
# Epoch 45/50
# 100/100 - 1s - 6ms/step - loss: 0.7679 - recall: 0.8160 - val_loss: 0.4566 - val_recall: 0.7239
# Epoch 46/50
# 100/100 - 1s - 6ms/step - loss: 0.7657 - recall: 0.8190 - val_loss: 0.4576 - val_recall: 0.7239
# Epoch 47/50
# 100/100 - 0s - 4ms/step - loss: 0.7628 - recall: 0.8213 - val_loss: 0.4582 - val_recall: 0.7209
# Epoch 48/50
# 100/100 - 1s - 6ms/step - loss: 0.7605 - recall: 0.8198 - val_loss: 0.4595 - val_recall: 0.7209
# Epoch 49/50
# 100/100 - 0s - 3ms/step - loss: 0.7581 - recall: 0.8213 - val_loss: 0.4594 - val_recall: 0.7209
# Epoch 50/50
# 100/100 - 1s - 6ms/step - loss: 0.7558 - recall: 0.8213 - val_loss: 0.4591 - val_recall: 0.7178

# %%
plot_loss(history_1,'loss')

# %%
plot_recall(history_1, 'recall')

# %%
model_1_train_perf = model_performance_classification(model_1, X_train, y_train)
model_1_train_perf
# Out:
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy   Recall  Precision  F1 Score
# 0  0.840781  0.83589   0.575198  0.681463

# %%
model_1_val_perf = model_performance_classification(model_1, X_val, y_val)
model_1_val_perf
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.791875  0.717791   0.492632   0.58427

# %%
confusion_matrix(y_val, model_1.predict(X_val) > 0.05)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[291, 983],
#        [  6, 320]])

# %% [markdown]
# * The recall score of the model has improved.
#   * Training recall score is 0.55 while validation is 0.47
# * There is a slightly larger difference between the training data and the validation data
# * The loss function of the validation data meets its minimum after around 8 epochs

# %% [markdown]
# ### Neural Network with Adam Optimizer and Dropout

# %% [markdown]
# * Adding dropout to the Adam optimizer model
#   * 20% dropout on the 64 neuron layer, and 10% dropout on the 32 neuron layer

# %%
tf.keras.backend.clear_session()

# %%
# creating the neural network
model_2 = Sequential()
model_2.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
model_2.add(Dropout(0.1))
model_2.add(Dense(32, activation='relu'))
model_2.add(Dropout(0.1))
model_2.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,883 (11.27 KB)
#  Trainable params: 2,881 (11.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
optimizer = keras.optimizers.Adam()
model_2.compile(
    loss ='binary_crossentropy',
    optimizer = optimizer,
    metrics = ['recall']
)

# %%
history_2 = model_2.fit(
    X_train, y_train,
    validation_data = (X_val, y_val),
    batch_size = batch_size,
    epochs = epochs,
    class_weight = cw_dict,
    verbose = 2
)
# Out:
# Epoch 1/50
# 100/100 - 2s - 20ms/step - loss: 1.2482 - recall: 0.6327 - val_loss: 0.5712 - val_recall: 0.7730
# Epoch 2/50
# 100/100 - 0s - 4ms/step - loss: 1.1347 - recall: 0.7216 - val_loss: 0.5473 - val_recall: 0.7730
# Epoch 3/50
# 100/100 - 0s - 3ms/step - loss: 1.0798 - recall: 0.7446 - val_loss: 0.5273 - val_recall: 0.7730
# Epoch 4/50
# 100/100 - 1s - 6ms/step - loss: 1.0196 - recall: 0.7546 - val_loss: 0.4978 - val_recall: 0.7883
# Epoch 5/50
# 100/100 - 0s - 3ms/step - loss: 0.9827 - recall: 0.7561 - val_loss: 0.4906 - val_recall: 0.7822
# Epoch 6/50
# 100/100 - 0s - 3ms/step - loss: 0.9602 - recall: 0.7523 - val_loss: 0.4740 - val_recall: 0.7669
# Epoch 7/50
# 100/100 - 1s - 6ms/step - loss: 0.9442 - recall: 0.7554 - val_loss: 0.4772 - val_recall: 0.7638
# Epoch 8/50
# 100/100 - 1s - 6ms/step - loss: 0.9374 - recall: 0.7446 - val_loss: 0.4695 - val_recall: 0.7638
# Epoch 9/50
# 100/100 - 1s - 7ms/step - loss: 0.9329 - recall: 0.7592 - val_loss: 0.4597 - val_recall: 0.7485
# Epoch 10/50
# 100/100 - 1s - 8ms/step - loss: 0.9322 - recall: 0.7646 - val_loss: 0.4632 - val_recall: 0.7485
# Epoch 11/50
# 100/100 - 1s - 6ms/step - loss: 0.9275 - recall: 0.7538 - val_loss: 0.4614 - val_recall: 0.7485
# Epoch 12/50
# 100/100 - 1s - 7ms/step - loss: 0.9199 - recall: 0.7646 - val_loss: 0.4536 - val_recall: 0.7485
# Epoch 13/50
# 100/100 - 1s - 5ms/step - loss: 0.9162 - recall: 0.7607 - val_loss: 0.4602 - val_recall: 0.7546
# Epoch 14/50
# 100/100 - 1s - 7ms/step - loss: 0.9109 - recall: 0.7623 - val_loss: 0.4672 - val_recall: 0.7638
# Epoch 15/50
# 100/100 - 1s - 6ms/step - loss: 0.9091 - recall: 0.7707 - val_loss: 0.4595 - val_recall: 0.7485
# Epoch 16/50
# 100/100 - 0s - 4ms/step - loss: 0.8970 - recall: 0.7715 - val_loss: 0.4613 - val_recall: 0.7607
# Epoch 17/50
# 100/100 - 0s - 3ms/step - loss: 0.9087 - recall: 0.7646 - val_loss: 0.4591 - val_recall: 0.7454
# Epoch 18/50
# 100/100 - 0s - 3ms/step - loss: 0.8981 - recall: 0.7669 - val_loss: 0.4477 - val_recall: 0.7362
# Epoch 19/50
# 100/100 - 1s - 6ms/step - loss: 0.8911 - recall: 0.7676 - val_loss: 0.4571 - val_recall: 0.7515
# Epoch 20/50
# 100/100 - 1s - 6ms/step - loss: 0.8919 - recall: 0.7730 - val_loss: 0.4589 - val_recall: 0.7393
# Epoch 21/50
# 100/100 - 1s - 6ms/step - loss: 0.8955 - recall: 0.7707 - val_loss: 0.4526 - val_recall: 0.7423
# Epoch 22/50
# 100/100 - 0s - 3ms/step - loss: 0.8822 - recall: 0.7761 - val_loss: 0.4508 - val_recall: 0.7393
# Epoch 23/50
# 100/100 - 0s - 3ms/step - loss: 0.8886 - recall: 0.7753 - val_loss: 0.4503 - val_recall: 0.7362
# Epoch 24/50
# 100/100 - 1s - 6ms/step - loss: 0.8786 - recall: 0.7707 - val_loss: 0.4602 - val_recall: 0.7331
# Epoch 25/50
# 100/100 - 1s - 6ms/step - loss: 0.8848 - recall: 0.7715 - val_loss: 0.4539 - val_recall: 0.7331
# Epoch 26/50
# 100/100 - 1s - 6ms/step - loss: 0.8726 - recall: 0.7784 - val_loss: 0.4490 - val_recall: 0.7331
# Epoch 27/50
# 100/100 - 0s - 3ms/step - loss: 0.8752 - recall: 0.7730 - val_loss: 0.4518 - val_recall: 0.7423
# Epoch 28/50
# 100/100 - 0s - 3ms/step - loss: 0.8751 - recall: 0.7753 - val_loss: 0.4508 - val_recall: 0.7485
# Epoch 29/50
# 100/100 - 1s - 6ms/step - loss: 0.8775 - recall: 0.7768 - val_loss: 0.4467 - val_recall: 0.7393
# Epoch 30/50
# 100/100 - 0s - 3ms/step - loss: 0.8668 - recall: 0.7715 - val_loss: 0.4483 - val_recall: 0.7362
# Epoch 31/50
# 100/100 - 1s - 6ms/step - loss: 0.8655 - recall: 0.7707 - val_loss: 0.4570 - val_recall: 0.7423
# Epoch 32/50
# 100/100 - 1s - 6ms/step - loss: 0.8659 - recall: 0.7799 - val_loss: 0.4545 - val_recall: 0.7270
# Epoch 33/50
# 100/100 - 0s - 3ms/step - loss: 0.8658 - recall: 0.7814 - val_loss: 0.4548 - val_recall: 0.7393
# Epoch 34/50
# 100/100 - 0s - 3ms/step - loss: 0.8599 - recall: 0.7753 - val_loss: 0.4516 - val_recall: 0.7301
# Epoch 35/50
# 100/100 - 1s - 6ms/step - loss: 0.8537 - recall: 0.7791 - val_loss: 0.4575 - val_recall: 0.7331
# Epoch 36/50
# 100/100 - 0s - 3ms/step - loss: 0.8608 - recall: 0.7692 - val_loss: 0.4522 - val_recall: 0.7301
# Epoch 37/50
# 100/100 - 1s - 6ms/step - loss: 0.8616 - recall: 0.7768 - val_loss: 0.4514 - val_recall: 0.7331
# Epoch 38/50
# 100/100 - 1s - 6ms/step - loss: 0.8573 - recall: 0.7807 - val_loss: 0.4500 - val_recall: 0.7362
# Epoch 39/50
# 100/100 - 1s - 6ms/step - loss: 0.8641 - recall: 0.7784 - val_loss: 0.4540 - val_recall: 0.7393
# Epoch 40/50
# 100/100 - 1s - 5ms/step - loss: 0.8487 - recall: 0.7837 - val_loss: 0.4451 - val_recall: 0.7270
# Epoch 41/50
# 100/100 - 1s - 6ms/step - loss: 0.8550 - recall: 0.7807 - val_loss: 0.4514 - val_recall: 0.7362
# Epoch 42/50
# 100/100 - 1s - 6ms/step - loss: 0.8324 - recall: 0.7830 - val_loss: 0.4397 - val_recall: 0.7301
# Epoch 43/50
# 100/100 - 0s - 4ms/step - loss: 0.8535 - recall: 0.7853 - val_loss: 0.4528 - val_recall: 0.7331
# Epoch 44/50
# 100/100 - 0s - 3ms/step - loss: 0.8413 - recall: 0.7876 - val_loss: 0.4452 - val_recall: 0.7301
# Epoch 45/50
# 100/100 - 0s - 3ms/step - loss: 0.8438 - recall: 0.7753 - val_loss: 0.4489 - val_recall: 0.7301
# Epoch 46/50
# 100/100 - 1s - 6ms/step - loss: 0.8385 - recall: 0.7868 - val_loss: 0.4489 - val_recall: 0.7362
# Epoch 47/50
# 100/100 - 0s - 3ms/step - loss: 0.8332 - recall: 0.7853 - val_loss: 0.4487 - val_recall: 0.7331
# Epoch 48/50
# 100/100 - 1s - 6ms/step - loss: 0.8389 - recall: 0.7899 - val_loss: 0.4497 - val_recall: 0.7209
# Epoch 49/50
# 100/100 - 0s - 3ms/step - loss: 0.8456 - recall: 0.7814 - val_loss: 0.4602 - val_recall: 0.7331
# Epoch 50/50
# 100/100 - 0s - 3ms/step - loss: 0.8315 - recall: 0.7868 - val_loss: 0.4431 - val_recall: 0.7209

# %%
plot_loss(history_2, 'loss')

# %%
plot_recall(history_2, 'recall')

# %%
model_2_train_perf = model_performance_classification(model_2, X_train, y_train)
model_2_train_perf
# Out:
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.825469  0.809816   0.548571  0.654072

# %%
model_2_val_perf = model_performance_classification(model_2, X_val, y_val)
model_2_val_perf
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.798125  0.720859   0.503212  0.592686

# %%
confusion_matrix(y_val, model_2.predict(X_val) > 0.05)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[ 195, 1079],
#        [   2,  324]])

# %% [markdown]
# * The model appears to be performing roughly the same after adding dropout
#   * However, there is more oscillation in the loss function and recall score

# %% [markdown]
# ### Neural Network with Balanced Data (by applying SMOTE) and SGD Optimizer

# %%
print('Before Oversampling, counts of label "Yes": {}'.format(sum(y_train==1)))
print('Before Oversampling, counts of label "No": {}'.format(sum(y_train==0)))

sm = SMOTE(random_state=1)
X_train_over, y_train_over = sm.fit_resample(X_train, y_train)

print('After Oversampling, counts of label "Yes": {}'.format(sum(y_train_over==1)))
print('After Oversampling, counts of label "No": {}'.format(sum(y_train_over==0)))

print('After Oversampling, the shape of train_X: {}'.format(X_train_over.shape))
print('After Oversampling, the shape of train_y: {}'.format(y_train_over.shape))
# Out:
# Before Oversampling, counts of label "Yes": 1304
# Before Oversampling, counts of label "No": 5096
# After Oversampling, counts of label "Yes": 5096
# After Oversampling, counts of label "No": 5096
# After Oversampling, the shape of train_X: (10192, 11)
# After Oversampling, the shape of train_y: (10192,)

# %%
tf.keras.backend.clear_session()

# %%
# creating the neural network
model_3 = Sequential()
model_3.add(Dense(64, activation='relu', input_dim=X_train_over.shape[1]))
model_3.add(Dense(32, activation='relu'))
model_3.add(Dense(1, activation='sigmoid'))

# %%
model_3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,881 (11.25 KB)
#  Trainable params: 2,881 (11.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = keras.optimizers.SGD()

model_3.compile(
    loss='binary_crossentropy',
    optimizer=optimizer,
    metrics=['recall']
)

# %%
history_3 = model_3.fit(
    X_train_over, y_train_over,
    validation_data = (X_val, y_val),
    batch_size = batch_size,
    epochs = epochs,
    class_weight = cw_dict,
    verbose = 2
)
# Out:
# Epoch 1/50
# 160/160 - 1s - 9ms/step - loss: 1.4185 - recall: 0.9943 - val_loss: 1.0755 - val_recall: 1.0000
# Epoch 2/50
# 160/160 - 1s - 6ms/step - loss: 1.3052 - recall: 0.9963 - val_loss: 1.0054 - val_recall: 0.9877
# Epoch 3/50
# 160/160 - 1s - 3ms/step - loss: 1.2521 - recall: 0.9896 - val_loss: 0.9518 - val_recall: 0.9632
# Epoch 4/50
# 160/160 - 1s - 4ms/step - loss: 1.2070 - recall: 0.9827 - val_loss: 0.9062 - val_recall: 0.9509
# Epoch 5/50
# 160/160 - 1s - 4ms/step - loss: 1.1649 - recall: 0.9721 - val_loss: 0.8680 - val_recall: 0.9448
# Epoch 6/50
# 160/160 - 1s - 4ms/step - loss: 1.1278 - recall: 0.9666 - val_loss: 0.8362 - val_recall: 0.9356
# Epoch 7/50
# 160/160 - 1s - 4ms/step - loss: 1.0977 - recall: 0.9621 - val_loss: 0.8115 - val_recall: 0.9356
# Epoch 8/50
# 160/160 - 1s - 4ms/step - loss: 1.0748 - recall: 0.9594 - val_loss: 0.7924 - val_recall: 0.9233
# Epoch 9/50
# 160/160 - 1s - 4ms/step - loss: 1.0581 - recall: 0.9572 - val_loss: 0.7787 - val_recall: 0.9202
# Epoch 10/50
# 160/160 - 1s - 8ms/step - loss: 1.0455 - recall: 0.9555 - val_loss: 0.7672 - val_recall: 0.9172
# Epoch 11/50
# 160/160 - 1s - 7ms/step - loss: 1.0355 - recall: 0.9551 - val_loss: 0.7581 - val_recall: 0.9141
# Epoch 12/50
# 160/160 - 0s - 3ms/step - loss: 1.0271 - recall: 0.9543 - val_loss: 0.7513 - val_recall: 0.9049
# Epoch 13/50
# 160/160 - 1s - 4ms/step - loss: 1.0198 - recall: 0.9535 - val_loss: 0.7453 - val_recall: 0.9018
# Epoch 14/50
# 160/160 - 0s - 2ms/step - loss: 1.0131 - recall: 0.9531 - val_loss: 0.7392 - val_recall: 0.8926
# Epoch 15/50
# 160/160 - 1s - 4ms/step - loss: 1.0069 - recall: 0.9531 - val_loss: 0.7346 - val_recall: 0.8896
# Epoch 16/50
# 160/160 - 0s - 2ms/step - loss: 1.0009 - recall: 0.9529 - val_loss: 0.7302 - val_recall: 0.8896
# Epoch 17/50
# 160/160 - 1s - 4ms/step - loss: 0.9950 - recall: 0.9531 - val_loss: 0.7255 - val_recall: 0.8896
# Epoch 18/50
# 160/160 - 1s - 4ms/step - loss: 0.9894 - recall: 0.9531 - val_loss: 0.7217 - val_recall: 0.8865
# Epoch 19/50
# 160/160 - 1s - 4ms/step - loss: 0.9839 - recall: 0.9527 - val_loss: 0.7183 - val_recall: 0.8834
# Epoch 20/50
# 160/160 - 1s - 4ms/step - loss: 0.9786 - recall: 0.9527 - val_loss: 0.7147 - val_recall: 0.8773
# Epoch 21/50
# 160/160 - 0s - 2ms/step - loss: 0.9735 - recall: 0.9535 - val_loss: 0.7103 - val_recall: 0.8742
# Epoch 22/50
# 160/160 - 0s - 3ms/step - loss: 0.9687 - recall: 0.9541 - val_loss: 0.7070 - val_recall: 0.8773
# Epoch 23/50
# 160/160 - 0s - 3ms/step - loss: 0.9639 - recall: 0.9539 - val_loss: 0.7033 - val_recall: 0.8773
# Epoch 24/50
# 160/160 - 1s - 4ms/step - loss: 0.9593 - recall: 0.9543 - val_loss: 0.6996 - val_recall: 0.8742
# Epoch 25/50
# 160/160 - 1s - 4ms/step - loss: 0.9548 - recall: 0.9545 - val_loss: 0.6962 - val_recall: 0.8681
# Epoch 26/50
# 160/160 - 0s - 2ms/step - loss: 0.9505 - recall: 0.9555 - val_loss: 0.6935 - val_recall: 0.8681
# Epoch 27/50
# 160/160 - 1s - 4ms/step - loss: 0.9462 - recall: 0.9558 - val_loss: 0.6905 - val_recall: 0.8681
# Epoch 28/50
# 160/160 - 1s - 4ms/step - loss: 0.9419 - recall: 0.9562 - val_loss: 0.6875 - val_recall: 0.8681
# Epoch 29/50
# 160/160 - 1s - 5ms/step - loss: 0.9376 - recall: 0.9568 - val_loss: 0.6840 - val_recall: 0.8650
# Epoch 30/50
# 160/160 - 1s - 4ms/step - loss: 0.9334 - recall: 0.9568 - val_loss: 0.6814 - val_recall: 0.8650
# Epoch 31/50
# 160/160 - 1s - 4ms/step - loss: 0.9292 - recall: 0.9568 - val_loss: 0.6789 - val_recall: 0.8650
# Epoch 32/50
# 160/160 - 1s - 4ms/step - loss: 0.9252 - recall: 0.9568 - val_loss: 0.6766 - val_recall: 0.8620
# Epoch 33/50
# 160/160 - 1s - 4ms/step - loss: 0.9212 - recall: 0.9580 - val_loss: 0.6740 - val_recall: 0.8589
# Epoch 34/50
# 160/160 - 1s - 6ms/step - loss: 0.9171 - recall: 0.9574 - val_loss: 0.6720 - val_recall: 0.8558
# Epoch 35/50
# 160/160 - 1s - 4ms/step - loss: 0.9130 - recall: 0.9572 - val_loss: 0.6691 - val_recall: 0.8558
# Epoch 36/50
# 160/160 - 1s - 4ms/step - loss: 0.9091 - recall: 0.9576 - val_loss: 0.6665 - val_recall: 0.8558
# Epoch 37/50
# 160/160 - 1s - 4ms/step - loss: 0.9052 - recall: 0.9588 - val_loss: 0.6629 - val_recall: 0.8558
# Epoch 38/50
# 160/160 - 0s - 2ms/step - loss: 0.9012 - recall: 0.9592 - val_loss: 0.6609 - val_recall: 0.8558
# Epoch 39/50
# 160/160 - 0s - 3ms/step - loss: 0.8973 - recall: 0.9594 - val_loss: 0.6584 - val_recall: 0.8528
# Epoch 40/50
# 160/160 - 0s - 3ms/step - loss: 0.8934 - recall: 0.9600 - val_loss: 0.6559 - val_recall: 0.8528
# Epoch 41/50
# 160/160 - 0s - 3ms/step - loss: 0.8894 - recall: 0.9606 - val_loss: 0.6534 - val_recall: 0.8497
# Epoch 42/50
# 160/160 - 0s - 3ms/step - loss: 0.8856 - recall: 0.9608 - val_loss: 0.6513 - val_recall: 0.8436
# Epoch 43/50
# 160/160 - 1s - 4ms/step - loss: 0.8818 - recall: 0.9606 - val_loss: 0.6488 - val_recall: 0.8405
# Epoch 44/50
# 160/160 - 0s - 3ms/step - loss: 0.8779 - recall: 0.9613 - val_loss: 0.6466 - val_recall: 0.8374
# Epoch 45/50
# 160/160 - 0s - 2ms/step - loss: 0.8741 - recall: 0.9617 - val_loss: 0.6439 - val_recall: 0.8374
# Epoch 46/50
# 160/160 - 1s - 4ms/step - loss: 0.8704 - recall: 0.9617 - val_loss: 0.6418 - val_recall: 0.8344
# Epoch 47/50
# 160/160 - 1s - 4ms/step - loss: 0.8666 - recall: 0.9621 - val_loss: 0.6400 - val_recall: 0.8313
# Epoch 48/50
# 160/160 - 0s - 2ms/step - loss: 0.8628 - recall: 0.9629 - val_loss: 0.6379 - val_recall: 0.8344
# Epoch 49/50
# 160/160 - 0s - 2ms/step - loss: 0.8591 - recall: 0.9645 - val_loss: 0.6357 - val_recall: 0.8313
# Epoch 50/50
# 160/160 - 0s - 2ms/step - loss: 0.8553 - recall: 0.9645 - val_loss: 0.6336 - val_recall: 0.8313

# %%
plot_loss(history_3, 'loss')

# %%
plot_recall(history_3, 'recall')

# %%
model_3_train_perf = model_performance_classification(model_3, X_train_over, y_train_over)
model_3_train_perf
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.801511  0.940149   0.736058  0.825679

# %%
model_3_val_perf = model_performance_classification(model_3, X_val, y_val)
model_3_val_perf
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.68125  0.831288   0.373278  0.515209

# %%
confusion_matrix(y_val, model_3.predict(X_val) > 0.05)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[ 180, 1094],
#        [   2,  324]])

# %% [markdown]
# * The loss function and recall score increased significantly
#   * As seen in the confusion matrix, there were only 5 false negative predictions

# %% [markdown]
# ### Neural Network with Balanced Data (by applying SMOTE) and Adam Optimizer

# %%
tf.keras.backend.clear_session()

# %%
# creating the neural network
model_4 = Sequential()
model_4.add(Dense(64, activation='relu', input_dim=X_train_over.shape[1]))
model_4.add(Dense(32, activation='relu'))
model_4.add(Dense(1, activation='sigmoid'))

# %%
model_4.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,881 (11.25 KB)
#  Trainable params: 2,881 (11.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = keras.optimizers.Adam()

model_4.compile(
    loss = 'binary_crossentropy',
    optimizer = optimizer,
    metrics = ['recall']
)

# %%
history_4 = model_4.fit(
    X_train_over, y_train_over,
    validation_data = (X_val, y_val),
    batch_size = batch_size,
    epochs = epochs,
    class_weight = cw_dict,
    verbose = 2
)
# Out:
# Epoch 1/50
# 160/160 - 3s - 19ms/step - loss: 1.3850 - recall: 0.9715 - val_loss: 0.8810 - val_recall: 0.9356
# Epoch 2/50
# 160/160 - 1s - 4ms/step - loss: 1.1148 - recall: 0.9653 - val_loss: 0.7669 - val_recall: 0.8988
# Epoch 3/50
# 160/160 - 0s - 3ms/step - loss: 1.0354 - recall: 0.9543 - val_loss: 0.7291 - val_recall: 0.8896
# Epoch 4/50
# 160/160 - 1s - 4ms/step - loss: 1.0022 - recall: 0.9523 - val_loss: 0.7130 - val_recall: 0.8650
# Epoch 5/50
# 160/160 - 1s - 4ms/step - loss: 0.9797 - recall: 0.9533 - val_loss: 0.7015 - val_recall: 0.8650
# Epoch 6/50
# 160/160 - 0s - 3ms/step - loss: 0.9613 - recall: 0.9545 - val_loss: 0.6930 - val_recall: 0.8558
# Epoch 7/50
# 160/160 - 0s - 3ms/step - loss: 0.9462 - recall: 0.9555 - val_loss: 0.6872 - val_recall: 0.8558
# Epoch 8/50
# 160/160 - 0s - 3ms/step - loss: 0.9327 - recall: 0.9572 - val_loss: 0.6842 - val_recall: 0.8528
# Epoch 9/50
# 160/160 - 1s - 4ms/step - loss: 0.9201 - recall: 0.9584 - val_loss: 0.6806 - val_recall: 0.8466
# Epoch 10/50
# 160/160 - 1s - 4ms/step - loss: 0.9078 - recall: 0.9608 - val_loss: 0.6788 - val_recall: 0.8466
# Epoch 11/50
# 160/160 - 0s - 3ms/step - loss: 0.8962 - recall: 0.9631 - val_loss: 0.6757 - val_recall: 0.8466
# Epoch 12/50
# 160/160 - 1s - 4ms/step - loss: 0.8850 - recall: 0.9631 - val_loss: 0.6738 - val_recall: 0.8497
# Epoch 13/50
# 160/160 - 1s - 4ms/step - loss: 0.8741 - recall: 0.9659 - val_loss: 0.6735 - val_recall: 0.8466
# Epoch 14/50
# 160/160 - 0s - 3ms/step - loss: 0.8635 - recall: 0.9666 - val_loss: 0.6740 - val_recall: 0.8497
# Epoch 15/50
# 160/160 - 0s - 3ms/step - loss: 0.8535 - recall: 0.9680 - val_loss: 0.6720 - val_recall: 0.8374
# Epoch 16/50
# 160/160 - 0s - 3ms/step - loss: 0.8436 - recall: 0.9684 - val_loss: 0.6721 - val_recall: 0.8374
# Epoch 17/50
# 160/160 - 1s - 4ms/step - loss: 0.8337 - recall: 0.9698 - val_loss: 0.6694 - val_recall: 0.8344
# Epoch 18/50
# 160/160 - 1s - 4ms/step - loss: 0.8244 - recall: 0.9700 - val_loss: 0.6686 - val_recall: 0.8344
# Epoch 19/50
# 160/160 - 0s - 3ms/step - loss: 0.8150 - recall: 0.9702 - val_loss: 0.6663 - val_recall: 0.8313
# Epoch 20/50
# 160/160 - 1s - 5ms/step - loss: 0.8058 - recall: 0.9708 - val_loss: 0.6647 - val_recall: 0.8252
# Epoch 21/50
# 160/160 - 1s - 5ms/step - loss: 0.7970 - recall: 0.9717 - val_loss: 0.6649 - val_recall: 0.8252
# Epoch 22/50
# 160/160 - 1s - 8ms/step - loss: 0.7881 - recall: 0.9733 - val_loss: 0.6653 - val_recall: 0.8252
# Epoch 23/50
# 160/160 - 1s - 7ms/step - loss: 0.7792 - recall: 0.9739 - val_loss: 0.6652 - val_recall: 0.8282
# Epoch 24/50
# 160/160 - 0s - 3ms/step - loss: 0.7705 - recall: 0.9755 - val_loss: 0.6637 - val_recall: 0.8313
# Epoch 25/50
# 160/160 - 1s - 4ms/step - loss: 0.7620 - recall: 0.9759 - val_loss: 0.6626 - val_recall: 0.8282
# Epoch 26/50
# 160/160 - 1s - 4ms/step - loss: 0.7537 - recall: 0.9763 - val_loss: 0.6615 - val_recall: 0.8282
# Epoch 27/50
# 160/160 - 1s - 4ms/step - loss: 0.7453 - recall: 0.9774 - val_loss: 0.6620 - val_recall: 0.8190
# Epoch 28/50
# 160/160 - 1s - 4ms/step - loss: 0.7371 - recall: 0.9780 - val_loss: 0.6616 - val_recall: 0.8190
# Epoch 29/50
# 160/160 - 0s - 3ms/step - loss: 0.7287 - recall: 0.9788 - val_loss: 0.6617 - val_recall: 0.8160
# Epoch 30/50
# 160/160 - 0s - 3ms/step - loss: 0.7209 - recall: 0.9794 - val_loss: 0.6602 - val_recall: 0.8160
# Epoch 31/50
# 160/160 - 1s - 4ms/step - loss: 0.7132 - recall: 0.9806 - val_loss: 0.6628 - val_recall: 0.8160
# Epoch 32/50
# 160/160 - 1s - 4ms/step - loss: 0.7057 - recall: 0.9804 - val_loss: 0.6660 - val_recall: 0.8160
# Epoch 33/50
# 160/160 - 1s - 4ms/step - loss: 0.6980 - recall: 0.9816 - val_loss: 0.6658 - val_recall: 0.8129
# Epoch 34/50
# 160/160 - 1s - 4ms/step - loss: 0.6908 - recall: 0.9821 - val_loss: 0.6661 - val_recall: 0.8129
# Epoch 35/50
# 160/160 - 0s - 3ms/step - loss: 0.6842 - recall: 0.9818 - val_loss: 0.6670 - val_recall: 0.8098
# Epoch 36/50
# 160/160 - 1s - 4ms/step - loss: 0.6779 - recall: 0.9823 - val_loss: 0.6681 - val_recall: 0.8037
# Epoch 37/50
# 160/160 - 1s - 4ms/step - loss: 0.6716 - recall: 0.9829 - val_loss: 0.6691 - val_recall: 0.8067
# Epoch 38/50
# 160/160 - 1s - 4ms/step - loss: 0.6657 - recall: 0.9831 - val_loss: 0.6721 - val_recall: 0.8006
# Epoch 39/50
# 160/160 - 1s - 4ms/step - loss: 0.6593 - recall: 0.9839 - val_loss: 0.6707 - val_recall: 0.8006
# Epoch 40/50
# 160/160 - 1s - 5ms/step - loss: 0.6538 - recall: 0.9831 - val_loss: 0.6740 - val_recall: 0.8037
# Epoch 41/50
# 160/160 - 1s - 4ms/step - loss: 0.6482 - recall: 0.9833 - val_loss: 0.6738 - val_recall: 0.8037
# Epoch 42/50
# 160/160 - 1s - 8ms/step - loss: 0.6430 - recall: 0.9837 - val_loss: 0.6763 - val_recall: 0.8006
# Epoch 43/50
# 160/160 - 1s - 7ms/step - loss: 0.6377 - recall: 0.9839 - val_loss: 0.6762 - val_recall: 0.7975
# Epoch 44/50
# 160/160 - 0s - 3ms/step - loss: 0.6326 - recall: 0.9843 - val_loss: 0.6773 - val_recall: 0.7945
# Epoch 45/50
# 160/160 - 1s - 4ms/step - loss: 0.6275 - recall: 0.9841 - val_loss: 0.6817 - val_recall: 0.7914
# Epoch 46/50
# 160/160 - 1s - 4ms/step - loss: 0.6229 - recall: 0.9843 - val_loss: 0.6830 - val_recall: 0.7883
# Epoch 47/50
# 160/160 - 0s - 3ms/step - loss: 0.6184 - recall: 0.9845 - val_loss: 0.6858 - val_recall: 0.7945
# Epoch 48/50
# 160/160 - 1s - 4ms/step - loss: 0.6140 - recall: 0.9853 - val_loss: 0.6852 - val_recall: 0.7945
# Epoch 49/50
# 160/160 - 1s - 4ms/step - loss: 0.6098 - recall: 0.9855 - val_loss: 0.6875 - val_recall: 0.7822
# Epoch 50/50
# 160/160 - 1s - 4ms/step - loss: 0.6056 - recall: 0.9861 - val_loss: 0.6888 - val_recall: 0.7822

# %%
plot_loss(history_4, 'loss')

# %%
plot_recall(history_4, 'recall')

# %%
model_4_train_perf = model_performance_classification(model_4, X_train_over, y_train_over)
model_4_train_perf
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.865483  0.984301   0.795307  0.879768

# %%
model_4_val_perf = model_performance_classification(model_4, X_val, y_val)
model_4_val_perf
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.719375  0.782209   0.402844  0.531804

# %%
confusion_matrix(y_val, model_4.predict(X_val) > 0.05)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[473, 801],
#        [ 20, 306]])

# %% [markdown]
# * When using oversampled data with the Adam optimizer, the model seems to be overfitting the data
#   * There is a substantial difference between the recall score of the training and validation data

# %% [markdown]
# ### Neural Network with Balanced Data (by applying SMOTE), Adam Optimizer, and Dropout

# %%
tf.keras.backend.clear_session()

# %%
# creating the neural network
model_5 = Sequential()
model_5.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
model_5.add(Dropout(0.2))
model_5.add(Dense(32, activation='relu'))
model_5.add(Dropout(0.1))
model_5.add(Dense(1, activation='sigmoid'))

# %%
model_5.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,881 (11.25 KB)
#  Trainable params: 2,881 (11.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = keras.optimizers.Adam()

model_5.compile(
    loss = 'binary_crossentropy',
    optimizer = optimizer,
    metrics = ['recall']
)

# %%
history_5 = model_5.fit(
    X_train_over, y_train_over,
    validation_data = (X_val, y_val),
    batch_size = batch_size,
    epochs = epochs,
    class_weight = cw_dict,
    verbose = 2
)
# Out:
# Epoch 1/50
# 160/160 - 2s - 14ms/step - loss: 1.4129 - recall: 0.9829 - val_loss: 0.9093 - val_recall: 0.9663
# Epoch 2/50
# 160/160 - 0s - 3ms/step - loss: 1.2034 - recall: 0.9664 - val_loss: 0.8183 - val_recall: 0.9325
# Epoch 3/50
# 160/160 - 0s - 3ms/step - loss: 1.1291 - recall: 0.9557 - val_loss: 0.7659 - val_recall: 0.9049
# Epoch 4/50
# 160/160 - 0s - 3ms/step - loss: 1.1050 - recall: 0.9523 - val_loss: 0.7738 - val_recall: 0.9141
# Epoch 5/50
# 160/160 - 1s - 5ms/step - loss: 1.0742 - recall: 0.9539 - val_loss: 0.7489 - val_recall: 0.9080
# Epoch 6/50
# 160/160 - 1s - 8ms/step - loss: 1.0637 - recall: 0.9519 - val_loss: 0.7455 - val_recall: 0.9080
# Epoch 7/50
# 160/160 - 1s - 7ms/step - loss: 1.0414 - recall: 0.9484 - val_loss: 0.7279 - val_recall: 0.8988
# Epoch 8/50
# 160/160 - 0s - 3ms/step - loss: 1.0414 - recall: 0.9519 - val_loss: 0.7248 - val_recall: 0.8957
# Epoch 9/50
# 160/160 - 1s - 4ms/step - loss: 1.0291 - recall: 0.9505 - val_loss: 0.7191 - val_recall: 0.8865
# Epoch 10/50
# 160/160 - 0s - 3ms/step - loss: 1.0294 - recall: 0.9504 - val_loss: 0.7302 - val_recall: 0.8896
# Epoch 11/50
# 160/160 - 1s - 4ms/step - loss: 1.0183 - recall: 0.9472 - val_loss: 0.7135 - val_recall: 0.8834
# Epoch 12/50
# 160/160 - 1s - 3ms/step - loss: 1.0107 - recall: 0.9492 - val_loss: 0.7202 - val_recall: 0.8804
# Epoch 13/50
# 160/160 - 1s - 3ms/step - loss: 1.0010 - recall: 0.9507 - val_loss: 0.7216 - val_recall: 0.8773
# Epoch 14/50
# 160/160 - 1s - 4ms/step - loss: 0.9869 - recall: 0.9531 - val_loss: 0.7178 - val_recall: 0.8712
# Epoch 15/50
# 160/160 - 1s - 4ms/step - loss: 0.9788 - recall: 0.9521 - val_loss: 0.6970 - val_recall: 0.8712
# Epoch 16/50
# 160/160 - 1s - 4ms/step - loss: 0.9785 - recall: 0.9535 - val_loss: 0.6942 - val_recall: 0.8712
# Epoch 17/50
# 160/160 - 1s - 4ms/step - loss: 0.9838 - recall: 0.9531 - val_loss: 0.7131 - val_recall: 0.8742
# Epoch 18/50
# 160/160 - 1s - 4ms/step - loss: 0.9651 - recall: 0.9545 - val_loss: 0.7062 - val_recall: 0.8681
# Epoch 19/50
# 160/160 - 0s - 3ms/step - loss: 0.9622 - recall: 0.9519 - val_loss: 0.7034 - val_recall: 0.8742
# Epoch 20/50
# 160/160 - 1s - 4ms/step - loss: 0.9493 - recall: 0.9568 - val_loss: 0.7055 - val_recall: 0.8712
# Epoch 21/50
# 160/160 - 1s - 4ms/step - loss: 0.9545 - recall: 0.9566 - val_loss: 0.7089 - val_recall: 0.8712
# Epoch 22/50
# 160/160 - 1s - 4ms/step - loss: 0.9422 - recall: 0.9590 - val_loss: 0.7175 - val_recall: 0.8712
# Epoch 23/50
# 160/160 - 0s - 3ms/step - loss: 0.9449 - recall: 0.9578 - val_loss: 0.7015 - val_recall: 0.8681
# Epoch 24/50
# 160/160 - 0s - 3ms/step - loss: 0.9453 - recall: 0.9568 - val_loss: 0.7084 - val_recall: 0.8650
# Epoch 25/50
# 160/160 - 1s - 6ms/step - loss: 0.9493 - recall: 0.9576 - val_loss: 0.7134 - val_recall: 0.8712
# Epoch 26/50
# 160/160 - 1s - 8ms/step - loss: 0.9359 - recall: 0.9596 - val_loss: 0.7085 - val_recall: 0.8650
# Epoch 27/50
# 160/160 - 1s - 8ms/step - loss: 0.9275 - recall: 0.9608 - val_loss: 0.6996 - val_recall: 0.8681
# Epoch 28/50
# 160/160 - 1s - 6ms/step - loss: 0.9305 - recall: 0.9600 - val_loss: 0.7111 - val_recall: 0.8650
# Epoch 29/50
# 160/160 - 0s - 3ms/step - loss: 0.9219 - recall: 0.9582 - val_loss: 0.6914 - val_recall: 0.8620
# Epoch 30/50
# 160/160 - 1s - 4ms/step - loss: 0.9286 - recall: 0.9574 - val_loss: 0.7082 - val_recall: 0.8712
# Epoch 31/50
# 160/160 - 1s - 4ms/step - loss: 0.9100 - recall: 0.9588 - val_loss: 0.7017 - val_recall: 0.8620
# Epoch 32/50
# 160/160 - 1s - 4ms/step - loss: 0.9174 - recall: 0.9588 - val_loss: 0.6967 - val_recall: 0.8650
# Epoch 33/50
# 160/160 - 1s - 4ms/step - loss: 0.9041 - recall: 0.9623 - val_loss: 0.6983 - val_recall: 0.8650
# Epoch 34/50
# 160/160 - 0s - 3ms/step - loss: 0.9100 - recall: 0.9615 - val_loss: 0.7040 - val_recall: 0.8589
# Epoch 35/50
# 160/160 - 0s - 3ms/step - loss: 0.9135 - recall: 0.9586 - val_loss: 0.7134 - val_recall: 0.8650
# Epoch 36/50
# 160/160 - 1s - 4ms/step - loss: 0.8956 - recall: 0.9627 - val_loss: 0.6896 - val_recall: 0.8558
# Epoch 37/50
# 160/160 - 1s - 4ms/step - loss: 0.8961 - recall: 0.9635 - val_loss: 0.6813 - val_recall: 0.8558
# Epoch 38/50
# 160/160 - 1s - 4ms/step - loss: 0.8906 - recall: 0.9621 - val_loss: 0.7075 - val_recall: 0.8558
# Epoch 39/50
# 160/160 - 0s - 3ms/step - loss: 0.8966 - recall: 0.9627 - val_loss: 0.7166 - val_recall: 0.8558
# Epoch 40/50
# 160/160 - 0s - 3ms/step - loss: 0.8889 - recall: 0.9633 - val_loss: 0.6989 - val_recall: 0.8497
# Epoch 41/50
# 160/160 - 1s - 4ms/step - loss: 0.8927 - recall: 0.9615 - val_loss: 0.6980 - val_recall: 0.8466
# Epoch 42/50
# 160/160 - 1s - 4ms/step - loss: 0.8745 - recall: 0.9643 - val_loss: 0.7034 - val_recall: 0.8528
# Epoch 43/50
# 160/160 - 1s - 4ms/step - loss: 0.8851 - recall: 0.9641 - val_loss: 0.6920 - val_recall: 0.8466
# Epoch 44/50
# 160/160 - 1s - 4ms/step - loss: 0.8752 - recall: 0.9621 - val_loss: 0.6879 - val_recall: 0.8436
# Epoch 45/50
# 160/160 - 1s - 5ms/step - loss: 0.8759 - recall: 0.9627 - val_loss: 0.6986 - val_recall: 0.8558
# Epoch 46/50
# 160/160 - 1s - 8ms/step - loss: 0.8819 - recall: 0.9633 - val_loss: 0.6948 - val_recall: 0.8466
# Epoch 47/50
# 160/160 - 1s - 5ms/step - loss: 0.8720 - recall: 0.9608 - val_loss: 0.7005 - val_recall: 0.8497
# Epoch 48/50
# 160/160 - 1s - 5ms/step - loss: 0.8751 - recall: 0.9645 - val_loss: 0.7107 - val_recall: 0.8589
# Epoch 49/50
# 160/160 - 1s - 3ms/step - loss: 0.8689 - recall: 0.9645 - val_loss: 0.7088 - val_recall: 0.8589
# Epoch 50/50
# 160/160 - 1s - 3ms/step - loss: 0.8656 - recall: 0.9641 - val_loss: 0.6777 - val_recall: 0.8528

# %%
plot_loss(history_5, 'loss')

# %%
plot_recall(history_5, 'recall')

# %%
model_5_train_perf = model_performance_classification(model_5, X_train_over, y_train_over)
model_5_train_perf
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0    0.8125  0.973705   0.736311   0.83853

# %%
model_5_val_perf = model_performance_classification(model_5, X_val, y_val)
model_5_val_perf
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.673125  0.852761    0.36919  0.515292

# %%
confusion_matrix(y_val, model_5.predict(X_val) > 0.05)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[ 222, 1052],
#        [   7,  319]])

# %% [markdown]
# * Similarly to the Adam optimizer with dropout model above, this model, after adding dropout, does not improve the recall score
#   * Again, there is more oscillation in the model over each epoch
# * This model, however, is significantly less overfit the before adding dropout

# %% [markdown]
# ## Model Performance Comparison and Final Model Selection

# %%
# training performance comparison

models_train_comp_df = pd.concat(
    [
        model_train_perf.T,
        model_1_train_perf.T,
        model_2_train_perf.T,
        model_3_train_perf.T,
        model_4_train_perf.T,
        model_5_train_perf.T,
    ],
    axis=1,
)
models_train_comp_df.columns = [
    "Neural Network (SGD)",
    "Neural Network 1 (Adam)",
    "Neural Network 2 (Adam with Dropout)",
    "Neural Network 3 (SGD with Oversampling)",
    "Neural Network 4 (Adam with Oversampling)",
    "Neural Network 5 (Adam with Oversampling and Dropout)",
]

# %%
# validation performance comparison

models_val_comp_df = pd.concat(
    [
        model_val_perf.T,
        model_1_val_perf.T,
        model_2_val_perf.T,
        model_3_val_perf.T,
        model_4_val_perf.T,
        model_5_val_perf.T,
    ],
    axis=1,
)
models_val_comp_df.columns = [
    "Neural Network (SGD)",
    "Neural Network 1 (Adam)",
    "Neural Network 2 (Adam with Dropout)",
    "Neural Network 3 (SGD with Oversampling)",
    "Neural Network 4 (Adam with Oversampling)",
    "Neural Network 5 (Adam with Oversampling and Dropout)",
]

# %%
models_train_comp_df
# Out:
#            Neural Network (SGD)  Neural Network 1 (Adam)  \
# Accuracy               0.820156                 0.840781
# Recall                 0.773006                 0.835890
# Precision              0.541063                 0.575198
# F1 Score               0.636565                 0.681463
#
#            Neural Network 2 (Adam with Dropout)  \
# Accuracy                               0.825469
# Recall                                 0.809816
# Precision                              0.548571
# F1 Score                               0.654072
#
#            Neural Network 3 (SGD with Oversampling)  \
# Accuracy                                   0.801511
# Recall                                     0.940149
# Precision                                  0.736058
# F1 Score                                   0.825679
#
#            Neural Network 4 (Adam with Oversampling)  \
# Accuracy                                    0.865483
# Recall                                      0.984301
# Precision                                   0.795307
# F1 Score                                    0.879768
#
#            Neural Network 5 (Adam with Oversampling and Dropout)
# Accuracy                                            0.812500
# Recall                                              0.973705
# Precision                                           0.736311
# F1 Score                                            0.838530

# %%
models_val_comp_df
# Out:
#            Neural Network (SGD)  Neural Network 1 (Adam)  \
# Accuracy               0.801250                 0.791875
# Recall                 0.705521                 0.717791
# Precision              0.508850                 0.492632
# F1 Score               0.591260                 0.584270
#
#            Neural Network 2 (Adam with Dropout)  \
# Accuracy                               0.798125
# Recall                                 0.720859
# Precision                              0.503212
# F1 Score                               0.592686
#
#            Neural Network 3 (SGD with Oversampling)  \
# Accuracy                                   0.681250
# Recall                                     0.831288
# Precision                                  0.373278
# F1 Score                                   0.515209
#
#            Neural Network 4 (Adam with Oversampling)  \
# Accuracy                                    0.719375
# Recall                                      0.782209
# Precision                                   0.402844
# F1 Score                                    0.531804
#
#            Neural Network 5 (Adam with Oversampling and Dropout)
# Accuracy                                            0.673125
# Recall                                              0.852761
# Precision                                           0.369190
# F1 Score                                            0.515292

# %% [markdown]
# * Based on the metrics above from all of the models, the Neural Network with SGD optimizer and Oversampled data performs the best.
# * The model with the Adam optimizer, Oversampled data, and Dropout also performed well on the training and validation data
#   * The Adam with Oversampling model was originally overfit, but utilizing dropout in the hidden layers helped the model generalize the data better
# * The recall scores of the models without oversampled data underperform due the class imbalance of the dataset

# %%
model_test_perf = model_performance_classification(model_3, X_test, y_test)
model_test_perf
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0     0.685  0.840295   0.377067  0.520548

# %%
confusion_matrix(y_test, model_3.predict(X_test) > 0.05)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[ 199, 1394],
#        [   6,  401]])

# %%
X_test.shape[0]
# Out:
# 2000

# %% [markdown]
# * Using model 3 (SGD with Oversampling), the model performs with a recall score of 0.68. As shown with the confusion matrix, only 9 out of 2000 customers in the unseen testing dataset were wrongly classified as false negatives.
#   * The large number in the false positive category does tell us that the model tends to regard the majority of customer as "likely to churn." Essentially, the model is overly caution in identifying customers that are likely to churn and in turn, falsely classifies many false positives. However, false positive are not a concern for the bank

# %% [markdown]
# ## Actionable Insights and Business Recommendations

# %% [markdown]
# * The bank can use the model with SGD optimizer and oversampling techniques to predict which customers will churn. This model minimizes the number of false negatives (when the model predicts the will customer will stay, but they churn).
# * As found from EDA, older customers tend to be more likely to churn. Approximately 75% of customers that exited the bank were above the age of 40; 75% of the customers that did not churn were under the age of 40.
#   * Introducing some marketing to a slightly older demographic could target those who might be considering leaving the bank
# * All customers that owned 4 products from the bank churned, and the vast majority of customers that owned 3 products also churned.
#   * Customers may often rely on brand loyalty when choosing to purchase a product from a bank; however, owning more products from the same bank may lead to churning if they find better rates with another bank.
#   * Ensuring competitive rates on every product offered may help retain customers and encourage brand loyalty in a positive light
# * Bank members were less likely to churn than non-members. Offering incentives to becoming a member could encourage more customers to join while also helping to retain current customers.

# %% [markdown]
# <font size=6 color='blue'>Power Ahead</font>
# ___
