# %% [markdown]
# <a href="https://colab.research.google.com/github/jgabrielg99/Python/blob/main/Plant%20Seedlings%20Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computer Vision: Plant Seedlings Classification

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Context

# %% [markdown]
# In recent times, the field of agriculture has been in urgent need of modernizing, since the amount of manual work people need to put in to check if plants are growing correctly is still highly extensive. Despite several advances in agricultural technology, people working in the agricultural industry still need to have the ability to sort and recognize different plants and weeds, which takes a lot of time and effort in the long term. The potential is ripe for this trillion-dollar industry to be greatly impacted by technological innovations that cut down on the requirement for manual labor, and this is where Artificial Intelligence can actually benefit the workers in this field, as **the time and energy required to identify plant seedlings will be greatly shortened by the use of AI and Deep Learning.** The ability to do so far more efficiently and even more effectively than experienced manual labor, could lead to better crop yields, the freeing up of human inolvement for higher-order agricultural decision making, and in the long term will result in more sustainable environmental practices in agriculture as well.

# %% [markdown]
# ### Objective

# %% [markdown]
# The aim of this project is to Build a Convolutional Neural Netowrk to classify plant seedlings into their respective categories.

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# The Aarhus University Signal Processing group, in collaboration with the University of Southern Denmark, has recently released a dataset containing **images of unique plants belonging to 12 different species.**
#
# - The dataset can be download from Olympus.
# - The data file names are:
#     - images.npy
#     - Labels.csv
# - Due to the large volume of data, the images were converted to the images.npy file and the labels are also put into Labels.csv, so that you can work on the data/project seamlessly without having to worry about the high data volume.
#
# - The goal of the project is to create a classifier capable of determining a plant's species from an image.
#
# **List of Species**
#
# - Black-grass
# - Charlock
# - Cleavers
# - Common Chickweed
# - Common Wheat
# - Fat Hen
# - Loose Silky-bent
# - Maize
# - Scentless Mayweed
# - Shepherds Purse
# - Small-flowered Cranesbill
# - Sugar beet

# %% [markdown]
# ### **Note: Please use GPU runtime on Google Colab to execute the code faster.**

# %% [markdown]
# ## Importing necessary libraries

# %%
# Installing the libraries with the specified version.
# uncomment and run the following line if Google Colab is being used
# !pip install tensorflow==2.15.0 scikit-learn==1.2.2 seaborn==0.13.1 matplotlib==3.7.1 numpy==1.25.2 pandas==1.5.3 opencv-python==4.8.0.76 -q --user
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 MB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 64.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 48.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 28.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 54.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 36.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 40.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 47.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 22.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 6.8 MB/s eta 0:00:00
#   WARNING: The scripts f2py, f2py3 and f2py3.11 are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter, import_pb_to_tensorboard, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 1.5.3 which is incompatible.
# xarray 2025.3.1 requires pandas>=2.1, but you have pandas 1.5.3 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# jax 0.5.2 requires ml_dtypes>=0.4.0, but you have ml-dtypes 0.2.0 which is incompatible.
# dask-cudf-cu12 25.2.2 requires pandas<2.2.4dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# mizani 0.13.3 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# tensorstore 0.1.74 requires ml_dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.15.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.15.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.1 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.15.0 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.7 which is incompatible.
# dask-expr 1.1.21 requires pandas>=2, but you have pandas 1.5.3 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.7 which is incompatible.
# blosc2 3.3.1 requires numpy>=1.26, but you have numpy 1.25.2 which is incompatible.
# cudf-cu12 25.2.1 requires pandas<2.2.4dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.25.2 which is incompatible.

# %%
import os
import numpy as np                                                                               # Importing numpy for Matrix Operations
import pandas as pd                                                                              # Importing pandas to read CSV files
import matplotlib.pyplot as plt                                                                  # Importting matplotlib for Plotting and visualizing images
import math                                                                                      # Importing math module to perform mathematical operations
import cv2                                                                                       # Importing openCV for image processing
import seaborn as sns                                                                            # Importing seaborn to plot graphs
import random


# Tensorflow modules
import tensorflow as tf
from tensorflow.keras import backend
from tensorflow.keras.preprocessing.image import ImageDataGenerator                              # Importing the ImageDataGenerator for data augmentation
from tensorflow.keras.models import Sequential, Model                                            # Importing the sequential module to define a sequential model
from keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D,BatchNormalization # Defining all the layers to build our CNN Model
from tensorflow.keras.optimizers import Adam,SGD                                                 # Importing the optimizers which can be used in our model
from sklearn import preprocessing
from sklearn.preprocessing import LabelBinarizer                                                 # Importing the preprocessing module to preprocess the data
from sklearn.model_selection import train_test_split                                             # Importing train_test_split function to split the data into train and test
from sklearn.metrics import confusion_matrix                                                     # Importing confusion_matrix to plot the confusion matrix

# Display images using OpenCV
from google.colab.patches import cv2_imshow                                                      # Importing cv2_imshow from google.patches to display images

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
# Uncomment and run the below code if you are using google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
images = np.load('/content/drive/MyDrive/AIML Course/Files/images.npy')

# %%
labels = pd.read_csv('/content/drive/MyDrive/AIML Course/Files/Labels.csv')

# %% [markdown]
# ## Data Overview

# %% [markdown]
# ### Understand the shape of the dataset

# %%
images.shape
# Out:
# (4750, 128, 128, 3)

# %% [markdown]
# * There are 4750 images in this dataset
#   * The dimensions of each images are 128x128 pixels
#   * These are colored images, so there are 3 channels for each image (RGB)

# %%
labels.shape
# Out:
# (4750, 1)

# %% [markdown]
# * Each image is labeled, so there are the same number of labels as there are images

# %%
cv2_imshow(images[0])
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
plt.imshow(images[0])

# %%
# Converting the images from BGR to RGB using cvtColor function of OpenCV
for i in range(len(images)):
  images[i] = cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB)

# %% [markdown]
# * The images are now all converted to RBG
#   * As we can see, OpenCV reads images as BGR while matplotlib reads images as RGB
#   * Converting the images to RGB will help to more easily interpret each image

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# - EDA is an important part of any project involving data.
# - It is important to investigate and understand the data better before building a model with it.
# - A few questions have been mentioned below which will help you understand the data better.
# - A thorough analysis of the data, in addition to the questions mentioned below, should be done.

# %% [markdown]
# 1. How are these different category plant images different from each other?
# 2. Is the dataset provided an imbalance? (Check with using bar plots)

# %%
# function to display images from different categories
def plot_images(images, labels):
  num_classes=len(np.unique(labels))
  categories=np.unique(labels)
  keys=dict(labels['Label'])
  rows=3
  cols=4
  fig=plt.figure(figsize=(10,8))
  for i in range(cols):
    for j in range(rows):
      random_index=np.random.randint(0, len(labels))
      ax=fig.add_subplot(rows, cols, i*rows+j+1)
      ax.imshow(images[random_index, :])
      ax.set_title(keys[random_index])
  plt.show

# %%
plot_images(images, labels)

# %% [markdown]
# As we can see, the background of each of the images appears to be very similar. Some images appear to be more zoomed in than others as well, so applying data augmentation techniques will likely help our model by creating

# %%
sns.countplot(labels['Label'])
plt.xticks(rotation=90);

# %% [markdown]
# * The dataset is somewhat imbalanced. Some plant types have 600+ images while some types has less than 300.
#   * Data augmentation will help with this imbalance

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### Resize the images

# %% [markdown]
# As the size of the images is large, it may be computationally expensive to train on these larger images; therefore, it is preferable to reduce the image size from 128 to 64.

# %%
images_resized = []
height=64
width=64
dimensions=(width,height)
for i in range(len(images)):
  images_resized.append(cv2.resize(images[i], dimensions, interpolation=cv2.INTER_LINEAR))

# %%
plt.imshow(images_resized[0])

# %% [markdown]
# ### Data Preparation for Modeling

# %% [markdown]
# - Before you proceed to build a model, you need to split the data into train, test, and validation to be able to evaluate the model that you build on the train data
# - You'll have to encode categorical features and scale the pixel values.
# - You will build a model using the train data and then check its performance

# %% [markdown]
# **Split the dataset**

# %%
X_big, X_test, y_big, y_test = train_test_split(np.array(images_resized), labels, test_size=0.1, random_state=1, stratify=labels)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_big, y_big, test_size=0.1, random_state=1, stratify=y_big)

# %%
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (3847, 64, 64, 3) (3847, 1)
# (428, 64, 64, 3) (428, 1)
# (475, 64, 64, 3) (475, 1)

# %% [markdown]
# * The data is now split into a training set, validation set, and test set

# %% [markdown]
# ### Encode the target labels

# %%
enc = LabelBinarizer()
y_train_enc = enc.fit_transform(y_train)
y_val_enc = enc.transform(y_val)
y_test_enc = enc.transform(y_test)

# %%
class_names = enc.classes_
pd.DataFrame(class_names, columns=['Class Names'])
# Out:
#                   Class Names
# 0                 Black-grass
# 1                    Charlock
# 2                    Cleavers
# 3            Common Chickweed
# 4                Common wheat
# 5                     Fat Hen
# 6            Loose Silky-bent
# 7                       Maize
# 8           Scentless Mayweed
# 9             Shepherds Purse
# 10  Small-flowered Cranesbill
# 11                 Sugar beet

# %% [markdown]
# * Each of labels are now encoded as categorical values and are ready to be applied to our models

# %% [markdown]
# ### Data Normalization

# %%
X_train_norm = X_train.astype('float32')/255.0
X_val_norm = X_val.astype('float32')/255.0
X_test_norm = X_test.astype('float32')/255.0

# %% [markdown]
# * Normalizing the data simplifies our model by converting all of the values of each pixel into a range from 0-1 rather than 0-255

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### CNN Model

# %%
backend.clear_session()

# %%
np.random.seed(1)
random.seed(1)
tf.random.set_seed(1)

# %% [markdown]
# * Backend has been cleared and random seed it set to avoid consistent performance of our model

# %%
# creates a sequential neural network model
model = Sequential()

# convolution layer with 64 filters, 3x3 kernel size, padding 'same' so the output shape matches input shape
# input_shape is dimensions of the images after resizing
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)))

# max pooling layer to reduce size of output
model.add(MaxPooling2D((2, 2), padding='same'))

# additional convolution block to improve feature maps
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))

# flattening layer to convert 2x2 images to 1 dimensional array
model.add(Flatten())

# adding fully connected dense layers with 32 neurons
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))

# output layers with 12 neurons for 12 possible classes, softmax activation function
model.add(Dense(12, activation='softmax'))

# using Adam Optimizer
opt=Adam()

# compile model
model.compile(optimizer=opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# generate model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 64, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │       262,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 12)             │           396 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 282,828 (1.08 MB)
#  Trainable params: 282,828 (1.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_1 = model.fit(
    X_train_norm,
    y_train_enc,
    epochs=50,
    batch_size=32,
    verbose=2,
    validation_data=(X_val_norm, y_val_enc)
)
# Out:
# Epoch 1/50
# 121/121 - 8s - 67ms/step - accuracy: 0.1321 - loss: 2.4522 - val_accuracy: 0.2453 - val_loss: 2.4156
# Epoch 2/50
# 121/121 - 1s - 6ms/step - accuracy: 0.2163 - loss: 2.3658 - val_accuracy: 0.2991 - val_loss: 2.2154
# Epoch 3/50
# 121/121 - 2s - 14ms/step - accuracy: 0.3187 - loss: 2.0905 - val_accuracy: 0.4065 - val_loss: 1.8528
# Epoch 4/50
# 121/121 - 3s - 21ms/step - accuracy: 0.3592 - loss: 1.8825 - val_accuracy: 0.4322 - val_loss: 1.7074
# Epoch 5/50
# 121/121 - 1s - 7ms/step - accuracy: 0.3782 - loss: 1.7705 - val_accuracy: 0.4720 - val_loss: 1.5890
# Epoch 6/50
# 121/121 - 1s - 6ms/step - accuracy: 0.3943 - loss: 1.6984 - val_accuracy: 0.5023 - val_loss: 1.5355
# Epoch 7/50
# 121/121 - 1s - 6ms/step - accuracy: 0.4180 - loss: 1.6034 - val_accuracy: 0.5257 - val_loss: 1.4845
# Epoch 8/50
# 121/121 - 1s - 6ms/step - accuracy: 0.4294 - loss: 1.5931 - val_accuracy: 0.5164 - val_loss: 1.4571
# Epoch 9/50
# 121/121 - 1s - 10ms/step - accuracy: 0.4544 - loss: 1.5232 - val_accuracy: 0.5701 - val_loss: 1.3738
# Epoch 10/50
# 121/121 - 1s - 6ms/step - accuracy: 0.4536 - loss: 1.4822 - val_accuracy: 0.5491 - val_loss: 1.3634
# Epoch 11/50
# 121/121 - 1s - 10ms/step - accuracy: 0.4780 - loss: 1.4284 - val_accuracy: 0.6051 - val_loss: 1.2769
# Epoch 12/50
# 121/121 - 1s - 10ms/step - accuracy: 0.5092 - loss: 1.3770 - val_accuracy: 0.6121 - val_loss: 1.2448
# Epoch 13/50
# 121/121 - 1s - 11ms/step - accuracy: 0.5227 - loss: 1.3200 - val_accuracy: 0.6332 - val_loss: 1.2484
# Epoch 14/50
# 121/121 - 1s - 6ms/step - accuracy: 0.5415 - loss: 1.2747 - val_accuracy: 0.6121 - val_loss: 1.2234
# Epoch 15/50
# 121/121 - 1s - 11ms/step - accuracy: 0.5529 - loss: 1.2240 - val_accuracy: 0.6308 - val_loss: 1.2188
# Epoch 16/50
# 121/121 - 1s - 11ms/step - accuracy: 0.5701 - loss: 1.2044 - val_accuracy: 0.6332 - val_loss: 1.2065
# Epoch 17/50
# 121/121 - 1s - 6ms/step - accuracy: 0.5747 - loss: 1.1651 - val_accuracy: 0.6495 - val_loss: 1.1716
# Epoch 18/50
# 121/121 - 1s - 6ms/step - accuracy: 0.5716 - loss: 1.1701 - val_accuracy: 0.6192 - val_loss: 1.1631
# Epoch 19/50
# 121/121 - 1s - 6ms/step - accuracy: 0.5862 - loss: 1.1583 - val_accuracy: 0.6098 - val_loss: 1.2120
# Epoch 20/50
# 121/121 - 1s - 11ms/step - accuracy: 0.5836 - loss: 1.1432 - val_accuracy: 0.6168 - val_loss: 1.2526
# Epoch 21/50
# 121/121 - 1s - 10ms/step - accuracy: 0.5815 - loss: 1.1595 - val_accuracy: 0.6308 - val_loss: 1.2098
# Epoch 22/50
# 121/121 - 1s - 6ms/step - accuracy: 0.5958 - loss: 1.0892 - val_accuracy: 0.6449 - val_loss: 1.1462
# Epoch 23/50
# 121/121 - 1s - 10ms/step - accuracy: 0.6059 - loss: 1.0777 - val_accuracy: 0.6449 - val_loss: 1.1610
# Epoch 24/50
# 121/121 - 1s - 10ms/step - accuracy: 0.6179 - loss: 1.0449 - val_accuracy: 0.6472 - val_loss: 1.1707
# Epoch 25/50
# 121/121 - 1s - 6ms/step - accuracy: 0.6189 - loss: 1.0291 - val_accuracy: 0.6519 - val_loss: 1.1635
# Epoch 26/50
# 121/121 - 1s - 6ms/step - accuracy: 0.6228 - loss: 1.0030 - val_accuracy: 0.6449 - val_loss: 1.2185
# Epoch 27/50
# 121/121 - 1s - 12ms/step - accuracy: 0.6465 - loss: 0.9875 - val_accuracy: 0.6519 - val_loss: 1.1776
# Epoch 28/50
# 121/121 - 1s - 8ms/step - accuracy: 0.6600 - loss: 0.9479 - val_accuracy: 0.6565 - val_loss: 1.1879
# Epoch 29/50
# 121/121 - 1s - 9ms/step - accuracy: 0.6766 - loss: 0.8870 - val_accuracy: 0.6472 - val_loss: 1.2279
# Epoch 30/50
# 121/121 - 1s - 10ms/step - accuracy: 0.6652 - loss: 0.8957 - val_accuracy: 0.6495 - val_loss: 1.1682
# Epoch 31/50
# 121/121 - 1s - 6ms/step - accuracy: 0.6712 - loss: 0.9017 - val_accuracy: 0.6472 - val_loss: 1.2107
# Epoch 32/50
# 121/121 - 1s - 7ms/step - accuracy: 0.6862 - loss: 0.8593 - val_accuracy: 0.6752 - val_loss: 1.1887
# Epoch 33/50
# 121/121 - 1s - 10ms/step - accuracy: 0.6790 - loss: 0.8558 - val_accuracy: 0.6776 - val_loss: 1.1664
# Epoch 34/50
# 121/121 - 1s - 6ms/step - accuracy: 0.6792 - loss: 0.8551 - val_accuracy: 0.6682 - val_loss: 1.1743
# Epoch 35/50
# 121/121 - 1s - 10ms/step - accuracy: 0.6933 - loss: 0.8265 - val_accuracy: 0.6589 - val_loss: 1.2149
# Epoch 36/50
# 121/121 - 1s - 6ms/step - accuracy: 0.7037 - loss: 0.7958 - val_accuracy: 0.6916 - val_loss: 1.1404
# Epoch 37/50
# 121/121 - 1s - 6ms/step - accuracy: 0.7247 - loss: 0.7554 - val_accuracy: 0.6799 - val_loss: 1.1695
# Epoch 38/50
# 121/121 - 1s - 6ms/step - accuracy: 0.7226 - loss: 0.7315 - val_accuracy: 0.6846 - val_loss: 1.1446
# Epoch 39/50
# 121/121 - 1s - 10ms/step - accuracy: 0.7302 - loss: 0.7348 - val_accuracy: 0.7079 - val_loss: 1.1689
# Epoch 40/50
# 121/121 - 1s - 12ms/step - accuracy: 0.7302 - loss: 0.7234 - val_accuracy: 0.6776 - val_loss: 1.1624
# Epoch 41/50
# 121/121 - 1s - 10ms/step - accuracy: 0.7510 - loss: 0.6918 - val_accuracy: 0.6986 - val_loss: 1.2035
# Epoch 42/50
# 121/121 - 1s - 6ms/step - accuracy: 0.7453 - loss: 0.6920 - val_accuracy: 0.6869 - val_loss: 1.2205
# Epoch 43/50
# 121/121 - 1s - 6ms/step - accuracy: 0.7554 - loss: 0.6655 - val_accuracy: 0.6963 - val_loss: 1.2425
# Epoch 44/50
# 121/121 - 1s - 6ms/step - accuracy: 0.7549 - loss: 0.6611 - val_accuracy: 0.6799 - val_loss: 1.2212
# Epoch 45/50
# 121/121 - 1s - 10ms/step - accuracy: 0.7494 - loss: 0.6827 - val_accuracy: 0.6869 - val_loss: 1.2717
# Epoch 46/50
# 121/121 - 1s - 6ms/step - accuracy: 0.7731 - loss: 0.6156 - val_accuracy: 0.6869 - val_loss: 1.2441
# Epoch 47/50
# 121/121 - 1s - 10ms/step - accuracy: 0.7645 - loss: 0.6159 - val_accuracy: 0.6939 - val_loss: 1.2850
# Epoch 48/50
# 121/121 - 1s - 6ms/step - accuracy: 0.7728 - loss: 0.6107 - val_accuracy: 0.6752 - val_loss: 1.2798
# Epoch 49/50
# 121/121 - 1s - 7ms/step - accuracy: 0.7829 - loss: 0.5838 - val_accuracy: 0.6776 - val_loss: 1.3283
# Epoch 50/50
# 121/121 - 1s - 6ms/step - accuracy: 0.7827 - loss: 0.5781 - val_accuracy: 0.6729 - val_loss: 1.3416

# %%
plt.plot(history_1.history['accuracy'])
plt.plot(history_1.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# * The accuracy of the training data comes in around .89 and the accuracy of the validation data is around .72
#   * This does imply that there may be a bit of overfitting as the gap between training and validation is .17
#   * We can address this via adding more dropout or adding in a BatchNormalization layer

# %%
accuracy_1 = model.evaluate(X_test_norm, y_test_enc, verbose=2)
# Out:
# 15/15 - 1s - 40ms/step - accuracy: 0.6821 - loss: 1.2997

# %% [markdown]
# * Testing data is also coming in around .69

# %%
y_pred = model.predict(X_test_norm)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
y_pred
# Out:
# array([[1.92998123e-04, 2.38652875e-10, 2.71453189e-08, ...,
#         9.78872094e-09, 1.10951811e-03, 5.52126467e-02],
#        [1.08510617e-15, 1.30093833e-02, 1.20956041e-01, ...,
#         9.77288233e-04, 8.64472151e-01, 4.69668186e-04],
#        [8.00007491e-11, 3.51625094e-05, 8.97737872e-03, ...,
#         9.56287049e-03, 1.87942013e-02, 6.31929666e-04],
#        ...,
#        [7.08345535e-11, 8.79170299e-01, 5.27793765e-02, ...,
#         3.77051147e-05, 1.07154665e-04, 5.50736375e-02],
#        [2.73207112e-23, 8.86625981e-11, 6.03939044e-16, ...,
#         4.06461222e-05, 1.11933161e-06, 2.62427193e-06],
#        [4.22997073e-06, 1.12730078e-02, 3.34020779e-02, ...,
#         8.99535138e-03, 2.50320068e-06, 1.94232598e-01]], dtype=float32)

# %%
y_pred_arg=np.argmax(y_pred, axis=1)
y_test_arg=np.argmax(y_test_enc, axis=1)

confusion_matrix=tf.math.confusion_matrix(y_test_arg, y_pred_arg)
f, ax = plt.subplots(figsize=(10,8))
sns.heatmap(
    confusion_matrix,
    annot=True,
    linewidths=.4,
    fmt='d',
    square=True,
    ax=ax
)
plt.show()

# %% [markdown]
# * As we can see, a large number of the images in the testing data were correctly classified; however, there were some categories that the model struggled to identify
#   * For example, 18 image from class 6 were wrongly identified as class 0

# %% [markdown]
# ## Model Performance Improvement

# %% [markdown]
# **Reducing the Learning Rate:**
#
# **Hint**: Use **ReduceLRonPlateau()** function that will be used to decrease the learning rate by some factor, if the loss is not decreasing for some time. This may start decreasing the loss at a smaller learning rate. There is a possibility that the loss may still not decrease. This may lead to executing the learning rate reduction again in an attempt to achieve a lower loss.

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy',
                                            patience=3,
                                            verbose=1,
                                            factor=0.5,
                                            min_lr=0.00001)

# %% [markdown]
# ### **Data Augmentation**
#
# Remember, **data augmentation should not be used in the validation/test data set**.

# %%
backend.clear_session()

np.random.seed(1)
random.seed(1)
tf.random.set_seed(1)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=30,
    fill_mode='nearest'
)

# %%
# creates a sequential neural network model
model_2 = Sequential()

# convolution layer with 64 filters, 3x3 kernel size, padding 'same' so the output shape matches input shape
# input_shape is dimensions of the images after resizing
model_2.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)))

# max pooling layer to reduce size of output
model_2.add(MaxPooling2D((2, 2), padding='same'))

# additional convolution block to improve feature maps
model_2.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model_2.add(MaxPooling2D((2, 2), padding='same'))
model_2.add(BatchNormalization())

# flattening layer to convert 2x2 images to 1 dimensional array
model_2.add(Flatten())

# adding fully connected dense layers with 32 neurons
model_2.add(Dense(32, activation='relu'))
model_2.add(Dropout(0.3))

# output layers with 12 neurons for 12 possible classes, softmax activation function
model_2.add(Dense(12, activation='softmax'))

# using Adam Optimizer
opt=Adam()

# compile model
model_2.compile(optimizer=opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# generate model summary
model_2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 64, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │       262,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 12)             │           396 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 282,956 (1.08 MB)
#  Trainable params: 282,892 (1.08 MB)
#  Non-trainable params: 64 (256.00 B)

# %%
history_2 = model_2.fit(train_datagen.flow(
        X_train_norm,
        y_train_enc,
        batch_size=32,
        shuffle=False
        ),
    epochs=50,
    steps_per_epoch=X_train_norm.shape[0]//32,
    validation_data=(X_val_norm, y_val_enc),
    callbacks=[learning_rate_reduction],
    verbose=2
)
# Out:
# Epoch 1/50
# 120/120 - 11s - 91ms/step - accuracy: 0.3334 - loss: 2.0313 - val_accuracy: 0.5187 - val_loss: 2.3491 - learning_rate: 1.0000e-03
# Epoch 2/50
# 120/120 - 0s - 799us/step - accuracy: 0.5312 - loss: 1.6146 - val_accuracy: 0.5164 - val_loss: 2.3417 - learning_rate: 1.0000e-03
# Epoch 3/50
# 120/120 - 7s - 56ms/step - accuracy: 0.4944 - loss: 1.5240 - val_accuracy: 0.4112 - val_loss: 2.1909 - learning_rate: 1.0000e-03
# Epoch 4/50
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 120/120 - 0s - 808us/step - accuracy: 0.5938 - loss: 1.1819 - val_accuracy: 0.3925 - val_loss: 2.1880 - learning_rate: 1.0000e-03
# Epoch 5/50
# 120/120 - 11s - 89ms/step - accuracy: 0.5735 - loss: 1.2616 - val_accuracy: 0.6168 - val_loss: 1.7868 - learning_rate: 5.0000e-04
# Epoch 6/50
# 120/120 - 0s - 817us/step - accuracy: 0.6875 - loss: 1.2080 - val_accuracy: 0.6332 - val_loss: 1.7786 - learning_rate: 5.0000e-04
# Epoch 7/50
# 120/120 - 8s - 71ms/step - accuracy: 0.6008 - loss: 1.1686 - val_accuracy: 0.6706 - val_loss: 1.4152 - learning_rate: 5.0000e-04
# Epoch 8/50
# 120/120 - 0s - 778us/step - accuracy: 0.6875 - loss: 1.0100 - val_accuracy: 0.6776 - val_loss: 1.4003 - learning_rate: 5.0000e-04
# Epoch 9/50
# 120/120 - 7s - 54ms/step - accuracy: 0.6498 - loss: 1.0317 - val_accuracy: 0.5117 - val_loss: 1.5565 - learning_rate: 5.0000e-04
# Epoch 10/50
# 120/120 - 0s - 786us/step - accuracy: 0.7500 - loss: 0.9811 - val_accuracy: 0.5023 - val_loss: 1.5649 - learning_rate: 5.0000e-04
# Epoch 11/50
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 120/120 - 9s - 75ms/step - accuracy: 0.6768 - loss: 0.9612 - val_accuracy: 0.4556 - val_loss: 2.0071 - learning_rate: 5.0000e-04
# Epoch 12/50
# 120/120 - 0s - 2ms/step - accuracy: 0.7812 - loss: 0.7009 - val_accuracy: 0.4603 - val_loss: 1.9927 - learning_rate: 2.5000e-04
# Epoch 13/50
# 120/120 - 6s - 46ms/step - accuracy: 0.7088 - loss: 0.8637 - val_accuracy: 0.7593 - val_loss: 0.7822 - learning_rate: 2.5000e-04
# Epoch 14/50
# 120/120 - 0s - 744us/step - accuracy: 0.7500 - loss: 0.7575 - val_accuracy: 0.7687 - val_loss: 0.7651 - learning_rate: 2.5000e-04
# Epoch 15/50
# 120/120 - 11s - 89ms/step - accuracy: 0.7240 - loss: 0.8250 - val_accuracy: 0.7757 - val_loss: 0.7485 - learning_rate: 2.5000e-04
# Epoch 16/50
# 120/120 - 0s - 775us/step - accuracy: 0.6875 - loss: 0.9867 - val_accuracy: 0.7804 - val_loss: 0.7627 - learning_rate: 2.5000e-04
# Epoch 17/50
# 120/120 - 9s - 71ms/step - accuracy: 0.7245 - loss: 0.8042 - val_accuracy: 0.7593 - val_loss: 0.7887 - learning_rate: 2.5000e-04
# Epoch 18/50
# 120/120 - 0s - 784us/step - accuracy: 0.7500 - loss: 0.6864 - val_accuracy: 0.7687 - val_loss: 0.7783 - learning_rate: 2.5000e-04
# Epoch 19/50
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 120/120 - 6s - 50ms/step - accuracy: 0.7358 - loss: 0.7685 - val_accuracy: 0.7056 - val_loss: 0.9075 - learning_rate: 2.5000e-04
# Epoch 20/50
# 120/120 - 0s - 781us/step - accuracy: 0.7188 - loss: 0.9675 - val_accuracy: 0.7103 - val_loss: 0.8907 - learning_rate: 1.2500e-04
# Epoch 21/50
# 120/120 - 9s - 71ms/step - accuracy: 0.7539 - loss: 0.7184 - val_accuracy: 0.7523 - val_loss: 0.7935 - learning_rate: 1.2500e-04
# Epoch 22/50
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 120/120 - 0s - 1ms/step - accuracy: 0.8438 - loss: 0.5139 - val_accuracy: 0.7523 - val_loss: 0.7857 - learning_rate: 1.2500e-04
# Epoch 23/50
# 120/120 - 6s - 50ms/step - accuracy: 0.7644 - loss: 0.7074 - val_accuracy: 0.7804 - val_loss: 0.6955 - learning_rate: 6.2500e-05
# Epoch 24/50
# 120/120 - 0s - 787us/step - accuracy: 0.7500 - loss: 0.8684 - val_accuracy: 0.7804 - val_loss: 0.6969 - learning_rate: 6.2500e-05
# Epoch 25/50
# 120/120 - 4s - 36ms/step - accuracy: 0.7630 - loss: 0.6936 - val_accuracy: 0.8014 - val_loss: 0.6755 - learning_rate: 6.2500e-05
# Epoch 26/50
# 120/120 - 0s - 765us/step - accuracy: 0.7500 - loss: 0.6503 - val_accuracy: 0.8014 - val_loss: 0.6797 - learning_rate: 6.2500e-05
# Epoch 27/50
# 120/120 - 5s - 43ms/step - accuracy: 0.7672 - loss: 0.6890 - val_accuracy: 0.7710 - val_loss: 0.7364 - learning_rate: 6.2500e-05
# Epoch 28/50
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 120/120 - 0s - 1ms/step - accuracy: 0.7812 - loss: 0.6478 - val_accuracy: 0.7687 - val_loss: 0.7425 - learning_rate: 6.2500e-05
# Epoch 29/50
# 120/120 - 9s - 77ms/step - accuracy: 0.7803 - loss: 0.6607 - val_accuracy: 0.8037 - val_loss: 0.6688 - learning_rate: 3.1250e-05
# Epoch 30/50
# 120/120 - 0s - 758us/step - accuracy: 0.7812 - loss: 0.6375 - val_accuracy: 0.8037 - val_loss: 0.6686 - learning_rate: 3.1250e-05
# Epoch 31/50
# 120/120 - 6s - 49ms/step - accuracy: 0.7625 - loss: 0.6764 - val_accuracy: 0.7944 - val_loss: 0.6733 - learning_rate: 3.1250e-05
# Epoch 32/50
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 120/120 - 0s - 742us/step - accuracy: 0.7500 - loss: 0.6777 - val_accuracy: 0.7921 - val_loss: 0.6733 - learning_rate: 3.1250e-05
# Epoch 33/50
# 120/120 - 4s - 36ms/step - accuracy: 0.7738 - loss: 0.6685 - val_accuracy: 0.7944 - val_loss: 0.7007 - learning_rate: 1.5625e-05
# Epoch 34/50
# 120/120 - 0s - 759us/step - accuracy: 0.8125 - loss: 0.6242 - val_accuracy: 0.7921 - val_loss: 0.6976 - learning_rate: 1.5625e-05
# Epoch 35/50
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1e-05.
# 120/120 - 4s - 36ms/step - accuracy: 0.7722 - loss: 0.6622 - val_accuracy: 0.7710 - val_loss: 0.7150 - learning_rate: 1.5625e-05
# Epoch 36/50
# 120/120 - 0s - 1ms/step - accuracy: 0.7188 - loss: 0.7660 - val_accuracy: 0.7710 - val_loss: 0.7148 - learning_rate: 1.0000e-05
# Epoch 37/50
# 120/120 - 6s - 49ms/step - accuracy: 0.7819 - loss: 0.6454 - val_accuracy: 0.7944 - val_loss: 0.6707 - learning_rate: 1.0000e-05
# Epoch 38/50
# 120/120 - 0s - 781us/step - accuracy: 0.8125 - loss: 0.5848 - val_accuracy: 0.7967 - val_loss: 0.6710 - learning_rate: 1.0000e-05
# Epoch 39/50
# 120/120 - 4s - 37ms/step - accuracy: 0.7801 - loss: 0.6358 - val_accuracy: 0.7921 - val_loss: 0.6739 - learning_rate: 1.0000e-05
# Epoch 40/50
# 120/120 - 0s - 771us/step - accuracy: 0.7812 - loss: 0.5801 - val_accuracy: 0.7897 - val_loss: 0.6753 - learning_rate: 1.0000e-05
# Epoch 41/50
# 120/120 - 6s - 53ms/step - accuracy: 0.7740 - loss: 0.6576 - val_accuracy: 0.7967 - val_loss: 0.6702 - learning_rate: 1.0000e-05
# Epoch 42/50
# 120/120 - 0s - 2ms/step - accuracy: 0.7812 - loss: 0.5424 - val_accuracy: 0.7967 - val_loss: 0.6696 - learning_rate: 1.0000e-05
# Epoch 43/50
# 120/120 - 4s - 36ms/step - accuracy: 0.7780 - loss: 0.6441 - val_accuracy: 0.7967 - val_loss: 0.6686 - learning_rate: 1.0000e-05
# Epoch 44/50
# 120/120 - 0s - 787us/step - accuracy: 0.8125 - loss: 0.4193 - val_accuracy: 0.7967 - val_loss: 0.6690 - learning_rate: 1.0000e-05
# Epoch 45/50
# 120/120 - 5s - 42ms/step - accuracy: 0.7866 - loss: 0.6386 - val_accuracy: 0.7991 - val_loss: 0.6653 - learning_rate: 1.0000e-05
# Epoch 46/50
# 120/120 - 0s - 769us/step - accuracy: 0.8125 - loss: 0.5710 - val_accuracy: 0.7991 - val_loss: 0.6656 - learning_rate: 1.0000e-05
# Epoch 47/50
# 120/120 - 6s - 49ms/step - accuracy: 0.7819 - loss: 0.6503 - val_accuracy: 0.7850 - val_loss: 0.6908 - learning_rate: 1.0000e-05
# Epoch 48/50
# 120/120 - 0s - 754us/step - accuracy: 0.7500 - loss: 0.7000 - val_accuracy: 0.7850 - val_loss: 0.6923 - learning_rate: 1.0000e-05
# Epoch 49/50
# 120/120 - 9s - 76ms/step - accuracy: 0.7824 - loss: 0.6337 - val_accuracy: 0.7804 - val_loss: 0.7005 - learning_rate: 1.0000e-05
# Epoch 50/50
# 120/120 - 0s - 2ms/step - accuracy: 0.7812 - loss: 0.8636 - val_accuracy: 0.7804 - val_loss: 0.7001 - learning_rate: 1.0000e-05

# %%
plt.plot(history_2.history['accuracy'])
plt.plot(history_2.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# * This model's performance has significantly improve over our previous model's performance
#   * The training accuracy is .86, and the validation accuracy is .84
#   * Our model is generalizing the data much better and is no longer overfitting

# %%
accuracy_2 = model_2.evaluate(X_test_norm, y_test_enc, verbose=2)
# Out:
# 15/15 - 1s - 45ms/step - accuracy: 0.7832 - loss: 0.6924

# %% [markdown]
# * The accuracy on the test dataset is right where we expect it to be, coming in at .82

# %%
y_pred=model_2.predict(X_test_norm)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step

# %%
y_pred_arg=np.argmax(y_pred, axis=1)
y_test_arg=np.argmax(y_test_enc, axis=1)

confusion_matrix=tf.math.confusion_matrix(y_test_arg, y_pred_arg)
f, ax = plt.subplots(figsize=(10,8))
sns.heatmap(
    confusion_matrix,
    annot=True,
    linewidths=.4,
    fmt='d',
    square=True,
    ax=ax
)
plt.show()

# %% [markdown]
# * This model is able to correctly classify more of the images
#   * Originally there were 18 images in class 6 that were misclassified, this improved model has brought that number down to 12

# %%
backend.clear_session()

np.random.seed(1)
random.seed(1)
tf.random.set_seed(1)

# %%
vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=(64,64,3))
vgg_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 64, 64, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 8, 8, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 2, 2, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
for layer in vgg_model.layers:
  layer.trainable=False

# %%
model_3 = Sequential()

model_3.add(vgg_model)

model_3.add(Flatten())

model_3.add(Dense(64, activation='relu'))
model_3.add(Dropout(0.3))
model_3.add(BatchNormalization())

model_3.add(Dense(32, activation='relu'))
model_3.add(Dropout(0.3))

model_3.add(Dense(12, activation='softmax'))

opt=Adam()

model_3.compile(optimizer=opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])

model_3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 2, 2, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       131,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 12)             │           396 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,848,556 (56.64 MB)
#  Trainable params: 133,740 (522.42 KB)
#  Non-trainable params: 14,714,816 (56.13 MB)

# %%
history_3 = model_3.fit(train_datagen.flow(
    X_train_norm,
    y_train_enc,
    batch_size=64,
    shuffle=False),
                        epochs=50,
                        steps_per_epoch=X_train_norm.shape[0]//64,
                        validation_data=(X_val_norm, y_val_enc),
                        callbacks=[learning_rate_reduction],
                        verbose=2
)
# Out:
# Epoch 1/50
# 60/60 - 20s - 336ms/step - accuracy: 0.1560 - loss: 2.4483 - val_accuracy: 0.2944 - val_loss: 2.2518 - learning_rate: 1.0000e-03
# Epoch 2/50
# 60/60 - 1s - 12ms/step - accuracy: 0.2656 - loss: 2.1609 - val_accuracy: 0.3084 - val_loss: 2.2451 - learning_rate: 1.0000e-03
# Epoch 3/50
# 60/60 - 7s - 124ms/step - accuracy: 0.2746 - loss: 2.1519 - val_accuracy: 0.4486 - val_loss: 2.0176 - learning_rate: 1.0000e-03
# Epoch 4/50
# 60/60 - 0s - 6ms/step - accuracy: 0.2344 - loss: 2.1604 - val_accuracy: 0.4393 - val_loss: 2.0159 - learning_rate: 1.0000e-03
# Epoch 5/50
# 60/60 - 5s - 83ms/step - accuracy: 0.3222 - loss: 1.9911 - val_accuracy: 0.4322 - val_loss: 1.8476 - learning_rate: 1.0000e-03
# Epoch 6/50
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 60/60 - 0s - 6ms/step - accuracy: 0.2812 - loss: 1.9695 - val_accuracy: 0.4322 - val_loss: 1.8559 - learning_rate: 1.0000e-03
# Epoch 7/50
# 60/60 - 10s - 165ms/step - accuracy: 0.3471 - loss: 1.8817 - val_accuracy: 0.4626 - val_loss: 1.7592 - learning_rate: 5.0000e-04
# Epoch 8/50
# 60/60 - 0s - 5ms/step - accuracy: 0.2969 - loss: 1.7886 - val_accuracy: 0.4533 - val_loss: 1.7591 - learning_rate: 5.0000e-04
# Epoch 9/50
# 60/60 - 10s - 165ms/step - accuracy: 0.3669 - loss: 1.8121 - val_accuracy: 0.4673 - val_loss: 1.6657 - learning_rate: 5.0000e-04
# Epoch 10/50
# 60/60 - 0s - 5ms/step - accuracy: 0.4062 - loss: 1.7829 - val_accuracy: 0.4743 - val_loss: 1.6602 - learning_rate: 5.0000e-04
# Epoch 11/50
# 60/60 - 11s - 180ms/step - accuracy: 0.4002 - loss: 1.7669 - val_accuracy: 0.4790 - val_loss: 1.6105 - learning_rate: 5.0000e-04
# Epoch 12/50
# 60/60 - 0s - 5ms/step - accuracy: 0.2812 - loss: 1.9015 - val_accuracy: 0.4766 - val_loss: 1.6087 - learning_rate: 5.0000e-04
# Epoch 13/50
# 60/60 - 10s - 174ms/step - accuracy: 0.3928 - loss: 1.7419 - val_accuracy: 0.4813 - val_loss: 1.5989 - learning_rate: 5.0000e-04
# Epoch 14/50
# 60/60 - 0s - 5ms/step - accuracy: 0.4688 - loss: 1.6842 - val_accuracy: 0.4790 - val_loss: 1.5996 - learning_rate: 5.0000e-04
# Epoch 15/50
# 60/60 - 5s - 82ms/step - accuracy: 0.4026 - loss: 1.7147 - val_accuracy: 0.5304 - val_loss: 1.5111 - learning_rate: 5.0000e-04
# Epoch 16/50
# 60/60 - 0s - 5ms/step - accuracy: 0.4219 - loss: 1.6933 - val_accuracy: 0.5304 - val_loss: 1.5096 - learning_rate: 5.0000e-04
# Epoch 17/50
# 60/60 - 11s - 180ms/step - accuracy: 0.4282 - loss: 1.6531 - val_accuracy: 0.4743 - val_loss: 1.5129 - learning_rate: 5.0000e-04
# Epoch 18/50
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 60/60 - 0s - 5ms/step - accuracy: 0.4062 - loss: 1.7135 - val_accuracy: 0.4696 - val_loss: 1.5207 - learning_rate: 5.0000e-04
# Epoch 19/50
# 60/60 - 11s - 176ms/step - accuracy: 0.4356 - loss: 1.6350 - val_accuracy: 0.5187 - val_loss: 1.4903 - learning_rate: 2.5000e-04
# Epoch 20/50
# 60/60 - 0s - 6ms/step - accuracy: 0.4844 - loss: 1.5285 - val_accuracy: 0.5210 - val_loss: 1.4870 - learning_rate: 2.5000e-04
# Epoch 21/50
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 60/60 - 5s - 83ms/step - accuracy: 0.4500 - loss: 1.5911 - val_accuracy: 0.5210 - val_loss: 1.4444 - learning_rate: 2.5000e-04
# Epoch 22/50
# 60/60 - 0s - 5ms/step - accuracy: 0.4286 - loss: 1.9587 - val_accuracy: 0.5164 - val_loss: 1.4443 - learning_rate: 1.2500e-04
# Epoch 23/50
# 60/60 - 10s - 170ms/step - accuracy: 0.4539 - loss: 1.5718 - val_accuracy: 0.5444 - val_loss: 1.4275 - learning_rate: 1.2500e-04
# Epoch 24/50
# 60/60 - 0s - 5ms/step - accuracy: 0.4062 - loss: 1.5177 - val_accuracy: 0.5467 - val_loss: 1.4289 - learning_rate: 1.2500e-04
# Epoch 25/50
# 60/60 - 11s - 183ms/step - accuracy: 0.4613 - loss: 1.5608 - val_accuracy: 0.5421 - val_loss: 1.4332 - learning_rate: 1.2500e-04
# Epoch 26/50
# 60/60 - 0s - 5ms/step - accuracy: 0.4062 - loss: 1.7060 - val_accuracy: 0.5421 - val_loss: 1.4338 - learning_rate: 1.2500e-04
# Epoch 27/50
# 60/60 - 9s - 156ms/step - accuracy: 0.4618 - loss: 1.5441 - val_accuracy: 0.5561 - val_loss: 1.4261 - learning_rate: 1.2500e-04
# Epoch 28/50
# 60/60 - 0s - 6ms/step - accuracy: 0.4062 - loss: 1.5309 - val_accuracy: 0.5467 - val_loss: 1.4267 - learning_rate: 1.2500e-04
# Epoch 29/50
# 60/60 - 9s - 152ms/step - accuracy: 0.4718 - loss: 1.5330 - val_accuracy: 0.5280 - val_loss: 1.3992 - learning_rate: 1.2500e-04
# Epoch 30/50
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 60/60 - 0s - 6ms/step - accuracy: 0.5156 - loss: 1.3002 - val_accuracy: 0.5257 - val_loss: 1.3985 - learning_rate: 1.2500e-04
# Epoch 31/50
# 60/60 - 6s - 105ms/step - accuracy: 0.4748 - loss: 1.5216 - val_accuracy: 0.5280 - val_loss: 1.3878 - learning_rate: 6.2500e-05
# Epoch 32/50
# 60/60 - 0s - 5ms/step - accuracy: 0.5625 - loss: 1.3197 - val_accuracy: 0.5304 - val_loss: 1.3872 - learning_rate: 6.2500e-05
# Epoch 33/50
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 60/60 - 9s - 148ms/step - accuracy: 0.4724 - loss: 1.5170 - val_accuracy: 0.5491 - val_loss: 1.3750 - learning_rate: 6.2500e-05
# Epoch 34/50
# 60/60 - 0s - 6ms/step - accuracy: 0.5000 - loss: 1.5055 - val_accuracy: 0.5491 - val_loss: 1.3748 - learning_rate: 3.1250e-05
# Epoch 35/50
# 60/60 - 10s - 161ms/step - accuracy: 0.4761 - loss: 1.5160 - val_accuracy: 0.5514 - val_loss: 1.3694 - learning_rate: 3.1250e-05
# Epoch 36/50
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 60/60 - 0s - 5ms/step - accuracy: 0.4219 - loss: 1.4200 - val_accuracy: 0.5514 - val_loss: 1.3695 - learning_rate: 3.1250e-05
# Epoch 37/50
# 60/60 - 6s - 107ms/step - accuracy: 0.4877 - loss: 1.5112 - val_accuracy: 0.5467 - val_loss: 1.3640 - learning_rate: 1.5625e-05
# Epoch 38/50
# 60/60 - 0s - 6ms/step - accuracy: 0.4844 - loss: 1.5544 - val_accuracy: 0.5491 - val_loss: 1.3640 - learning_rate: 1.5625e-05
# Epoch 39/50
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1e-05.
# 60/60 - 5s - 82ms/step - accuracy: 0.4814 - loss: 1.5101 - val_accuracy: 0.5467 - val_loss: 1.3614 - learning_rate: 1.5625e-05
# Epoch 40/50
# 60/60 - 0s - 6ms/step - accuracy: 0.5469 - loss: 1.4050 - val_accuracy: 0.5467 - val_loss: 1.3615 - learning_rate: 1.0000e-05
# Epoch 41/50
# 60/60 - 10s - 166ms/step - accuracy: 0.4819 - loss: 1.5008 - val_accuracy: 0.5397 - val_loss: 1.3602 - learning_rate: 1.0000e-05
# Epoch 42/50
# 60/60 - 0s - 5ms/step - accuracy: 0.4531 - loss: 1.7112 - val_accuracy: 0.5397 - val_loss: 1.3600 - learning_rate: 1.0000e-05
# Epoch 43/50
# 60/60 - 11s - 187ms/step - accuracy: 0.4779 - loss: 1.5089 - val_accuracy: 0.5561 - val_loss: 1.3581 - learning_rate: 1.0000e-05
# Epoch 44/50
# 60/60 - 0s - 5ms/step - accuracy: 0.4375 - loss: 1.4772 - val_accuracy: 0.5584 - val_loss: 1.3584 - learning_rate: 1.0000e-05
# Epoch 45/50
# 60/60 - 5s - 82ms/step - accuracy: 0.4766 - loss: 1.4991 - val_accuracy: 0.5561 - val_loss: 1.3584 - learning_rate: 1.0000e-05
# Epoch 46/50
# 60/60 - 0s - 5ms/step - accuracy: 0.5000 - loss: 1.4740 - val_accuracy: 0.5561 - val_loss: 1.3585 - learning_rate: 1.0000e-05
# Epoch 47/50
# 60/60 - 10s - 167ms/step - accuracy: 0.4692 - loss: 1.5243 - val_accuracy: 0.5491 - val_loss: 1.3586 - learning_rate: 1.0000e-05
# Epoch 48/50
# 60/60 - 0s - 6ms/step - accuracy: 0.4375 - loss: 1.6608 - val_accuracy: 0.5491 - val_loss: 1.3584 - learning_rate: 1.0000e-05
# Epoch 49/50
# 60/60 - 6s - 96ms/step - accuracy: 0.4734 - loss: 1.4964 - val_accuracy: 0.5584 - val_loss: 1.3526 - learning_rate: 1.0000e-05
# Epoch 50/50
# 60/60 - 0s - 6ms/step - accuracy: 0.6250 - loss: 1.2327 - val_accuracy: 0.5584 - val_loss: 1.3528 - learning_rate: 1.0000e-05

# %%
plt.plot(history_3.history['accuracy'])
plt.plot(history_3.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
accuracy_3 = model_3.evaluate(X_test_norm, y_test_enc, verbose=2)
# Out:
# 15/15 - 2s - 142ms/step - accuracy: 0.5495 - loss: 1.3634

# %%
y_pred=model_3.predict(X_test_norm)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step

# %%
y_pred_arg=np.argmax(y_pred, axis=1)
y_test_arg=np.argmax(y_test_enc, axis=1)

confusion_matrix=tf.math.confusion_matrix(y_test_arg, y_pred_arg)
f, ax = plt.subplots(figsize=(10,8))
sns.heatmap(
    confusion_matrix,
    annot=True,
    linewidths=.4,
    fmt='d',
    square=True,
    ax=ax
)
plt.show()

# %% [markdown]
# * The 3rd model was built using the VGG16 model including the weights from the imagenet dataset
#   * This model did not perform well on our dataset

# %% [markdown]
# ## Final Model

# %%
model_comparison = pd.DataFrame(
    [accuracy_1, accuracy_2, accuracy_3],
    columns = ['Loss', 'Accuracy'],
    index=['Model_1', 'Model_2', 'Model_3']
)

model_comparison
# Out:
#              Loss  Accuracy
# Model_1  1.299696  0.682105
# Model_2  0.692428  0.783158
# Model_3  1.363371  0.549474

# %% [markdown]
# * According to the accurancy curve and confusion matrix. Model 2 (Dropout, BatchNormalization, and Learning Rate Monitoring) had the highest performance metrics from out 3 models
#   * The accuracy of Model_2 is .82 on the testing data set

# %% [markdown]
# ### Visualizing the prediction

# %%
# Visualizing the predicted and correct label of images from test data
plt.figure(figsize=(2,2))
plt.imshow(X_test[2])
plt.show()
print('Predicted Label', enc.inverse_transform(model_2.predict((X_test_norm[2].reshape(1,64,64,3)))))   # reshaping the input image as we are only trying to predict using a single image
print('True Label', enc.inverse_transform(y_test_enc)[2])                                               # using inverse_transform() to get the output label from the output vector

plt.figure(figsize=(2,2))
plt.imshow(X_test[35])
plt.show()
print('Predicted Label', enc.inverse_transform(model_2.predict((X_test_norm[35].reshape(1,64,64,3)))))  # reshaping the input image as we are only trying to predict using a single image
print('True Label', enc.inverse_transform(y_test_enc)[35])                                              # using inverse_transform() to get the output label from the output vector

plt.figure(figsize=(2,2))
plt.imshow(X_test[53])
plt.show()
print('Predicted Label', enc.inverse_transform(model_2.predict((X_test_norm[53].reshape(1,64,64,3)))))  # reshaping the input image as we are only trying to predict using a single image
print('True Label', enc.inverse_transform(y_test_enc)[53])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# Predicted Label ['Fat Hen']
# True Label Fat Hen
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Predicted Label ['Scentless Mayweed']
# True Label Scentless Mayweed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Predicted Label ['Common Chickweed']
# True Label Common Chickweed

# %% [markdown]
# ## Actionable Insights and Business Recommendations

# %% [markdown]
# * We can observe from the confusion matrix of each model that Model_2 was able to correctly classify the images in our 12 classes with the highest accuracy
#   * The test accuracy of Model_2 was 82%
# * Data Augmentation helped fix the class imbalance due to the differing number of images within each class
#   * Further Data Augmentation paramenters could be experimented with to further increase the model's accuracy
# * To further improve this model, the model could be trained on the original sized image; however, it will be more computational expensive
# * The most commonly misclassified images were those in classes 0 (Black Grass) and 6 (Loose Silky Bent)
# * Images sorted in these class may need addition identification proceedures

# %% [markdown]
# _____
